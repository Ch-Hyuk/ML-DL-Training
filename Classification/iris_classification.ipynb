# %% [markdown]
# ## iris 데이터에 따른 품종 구분
# - train 70%, test 30%
# - 4개의 입력층, 64개의 노드를 가지는 하나의 hidden node
# - sparse_categorical_crossentropy, 최적화 함수는 adam, 정확도는 accuracy
# - batch_size = 5, epoch = 30
# - 90% 이상의 hyperparameter tuning

# %%
import torch
import torch.nn as nn
from torch.utils.data import DataLoader, TensorDataset
import torch.optim as optim

from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split

# %%
iris = load_iris()
data,label = iris.data, iris.target
X_train, X_test, y_train, y_test = train_test_split(data, label, test_size=0.3)

print('train_data: ', len(X_train))
print('test_data: ', len(X_test))
# Out:
# train_data:  105
# test_data:  45

# %%
X_train = torch.from_numpy(X_train).float()
y_train = torch.from_numpy(y_train).long()

X_test = torch.from_numpy(X_test).float()
y_test = torch.from_numpy(y_test).float()

train_set = TensorDataset(X_train, y_train)

train_loader = DataLoader(train_set, batch_size=6, shuffle=True)

# %%
class Net(nn.Module):

  def __init__(self):
    super(Net, self).__init__()

    self.hidden_layer = nn.Linear(4, 64)
    self.bn = nn.BatchNorm1d(64)
    self.act = nn.ReLU()
    self.dropout = nn.Dropout(0.3)

    #return 값 조정
  def forward(self, x):
    x = self.act(self.hidden_layer(x))

    return x
  
  def forward_batch(self, x):
    x = self.act(self.bn(self.hidden_layer(x)))

  def forward_drop(self, x):
    x = self.act(self.dropout(self.hidden_layer(x)))

# %%
net = Net()
print(net)
# Out:
# Net(
#   (hidden_layer): Linear(in_features=4, out_features=64, bias=True)
#   (bn): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (act): ReLU()
#   (dropout): Dropout(p=0.3, inplace=False)
# )

# %%
optimizer = optim.Adam(net.parameters(), lr=0.005)
criterion = nn.CrossEntropyLoss()
epochs = 200

# %%
losses = list()
accuracies = list()

for epoch in range(epochs):
    epoch_loss = 0
    epoch_accuracy = 0
    for X, y in train_loader:

        optimizer.zero_grad()

        output = net(X)

        loss = criterion(output, y)
        loss.backward()

        optimizer.step()

        _,predicted = torch.max(output, dim=1) 
    
        accuracy = (predicted ==y).sum().item()
        epoch_loss += loss.item()
        epoch_accuracy += accuracy

    epoch_loss /= len(train_loader)
    epoch_accuracy /= len(X_train)
    print('epoch : {}, \tloss : {}, \taccuracy : {}'.format(str(epoch+1).zfill(3),round(epoch_loss, 4),round(epoch_accuracy, 4)))

    losses.append(epoch_loss)
    accuracies.append(epoch_accuracy)
# Out:
# epoch : 001, 	loss : 3.6415, 	accuracy : 0.0
# epoch : 002, 	loss : 2.3218, 	accuracy : 0.2571
# epoch : 003, 	loss : 1.7212, 	accuracy : 0.3524
# epoch : 004, 	loss : 1.4377, 	accuracy : 0.3524
# epoch : 005, 	loss : 1.2735, 	accuracy : 0.3429
# epoch : 006, 	loss : 1.163, 	accuracy : 0.2476
# epoch : 007, 	loss : 1.0695, 	accuracy : 0.3524
# epoch : 008, 	loss : 0.9843, 	accuracy : 0.4762
# epoch : 009, 	loss : 0.9106, 	accuracy : 0.5429
# epoch : 010, 	loss : 0.8549, 	accuracy : 0.5619
# epoch : 011, 	loss : 0.8071, 	accuracy : 0.5524
# epoch : 012, 	loss : 0.7734, 	accuracy : 0.5905
# epoch : 013, 	loss : 0.7266, 	accuracy : 0.6571
# epoch : 014, 	loss : 0.7113, 	accuracy : 0.6286
# epoch : 015, 	loss : 0.6766, 	accuracy : 0.6762
# epoch : 016, 	loss : 0.6532, 	accuracy : 0.7429
# epoch : 017, 	loss : 0.6361, 	accuracy : 0.6952
# epoch : 018, 	loss : 0.6201, 	accuracy : 0.7048
# epoch : 019, 	loss : 0.6101, 	accuracy : 0.7333
# epoch : 020, 	loss : 0.602, 	accuracy : 0.6762
# epoch : 021, 	loss : 0.5775, 	accuracy : 0.7333
# epoch : 022, 	loss : 0.564, 	accuracy : 0.7714
# epoch : 023, 	loss : 0.5417, 	accuracy : 0.7238
# epoch : 024, 	loss : 0.5318, 	accuracy : 0.9143
# epoch : 025, 	loss : 0.5306, 	accuracy : 0.9333
# epoch : 026, 	loss : 0.5195, 	accuracy : 0.8381
# epoch : 027, 	loss : 0.5088, 	accuracy : 0.8952
# epoch : 028, 	loss : 0.5042, 	accuracy : 0.7524
# epoch : 029, 	loss : 0.4988, 	accuracy : 0.8952
# epoch : 030, 	loss : 0.5009, 	accuracy : 0.7905
# epoch : 031, 	loss : 0.4845, 	accuracy : 0.9524
# epoch : 032, 	loss : 0.4747, 	accuracy : 0.9429
# epoch : 033, 	loss : 0.4664, 	accuracy : 0.8381
# epoch : 034, 	loss : 0.4722, 	accuracy : 0.8952
# epoch : 035, 	loss : 0.4855, 	accuracy : 0.7333
# epoch : 036, 	loss : 0.4672, 	accuracy : 0.8571
# epoch : 037, 	loss : 0.4621, 	accuracy : 0.8095
# epoch : 038, 	loss : 0.4445, 	accuracy : 0.9429
# epoch : 039, 	loss : 0.4389, 	accuracy : 0.8571
# epoch : 040, 	loss : 0.4292, 	accuracy : 0.9429
# epoch : 041, 	loss : 0.4253, 	accuracy : 0.9429
# epoch : 042, 	loss : 0.4205, 	accuracy : 0.9429
# epoch : 043, 	loss : 0.4277, 	accuracy : 0.9714
# epoch : 044, 	loss : 0.419, 	accuracy : 0.9333
# epoch : 045, 	loss : 0.4105, 	accuracy : 0.9619
# epoch : 046, 	loss : 0.4087, 	accuracy : 0.9429
# epoch : 047, 	loss : 0.4085, 	accuracy : 0.9619
# epoch : 048, 	loss : 0.3957, 	accuracy : 0.9714
# epoch : 049, 	loss : 0.3916, 	accuracy : 0.9619
# epoch : 050, 	loss : 0.393, 	accuracy : 0.9429
# epoch : 051, 	loss : 0.3838, 	accuracy : 0.9619
# epoch : 052, 	loss : 0.3936, 	accuracy : 0.9429
# epoch : 053, 	loss : 0.3858, 	accuracy : 0.9619
# epoch : 054, 	loss : 0.3819, 	accuracy : 0.9524
# epoch : 055, 	loss : 0.3749, 	accuracy : 0.9429
# epoch : 056, 	loss : 0.3745, 	accuracy : 0.9524
# epoch : 057, 	loss : 0.3679, 	accuracy : 0.9524
# epoch : 058, 	loss : 0.3642, 	accuracy : 0.9619
# epoch : 059, 	loss : 0.3671, 	accuracy : 0.9524
# epoch : 060, 	loss : 0.3656, 	accuracy : 0.9524
# epoch : 061, 	loss : 0.3585, 	accuracy : 0.9524
# epoch : 062, 	loss : 0.3569, 	accuracy : 0.9714
# epoch : 063, 	loss : 0.3503, 	accuracy : 0.9619
# epoch : 064, 	loss : 0.3502, 	accuracy : 0.9429
# epoch : 065, 	loss : 0.348, 	accuracy : 0.9619
# epoch : 066, 	loss : 0.3538, 	accuracy : 0.9238
# epoch : 067, 	loss : 0.3457, 	accuracy : 0.9143
# epoch : 068, 	loss : 0.3307, 	accuracy : 0.9524
# epoch : 069, 	loss : 0.3415, 	accuracy : 0.9619
# epoch : 070, 	loss : 0.3352, 	accuracy : 0.9524
# epoch : 071, 	loss : 0.3263, 	accuracy : 0.9619
# epoch : 072, 	loss : 0.3248, 	accuracy : 0.9619
# epoch : 073, 	loss : 0.3179, 	accuracy : 0.9524
# epoch : 074, 	loss : 0.326, 	accuracy : 0.9524
# epoch : 075, 	loss : 0.3227, 	accuracy : 0.9429
# epoch : 076, 	loss : 0.3267, 	accuracy : 0.9524
# epoch : 077, 	loss : 0.3134, 	accuracy : 0.9619
# epoch : 078, 	loss : 0.3138, 	accuracy : 0.9619
# epoch : 079, 	loss : 0.3089, 	accuracy : 0.9524
# epoch : 080, 	loss : 0.3051, 	accuracy : 0.9429
# epoch : 081, 	loss : 0.3054, 	accuracy : 0.9524
# epoch : 082, 	loss : 0.3076, 	accuracy : 0.9524
# epoch : 083, 	loss : 0.3019, 	accuracy : 0.9524
# epoch : 084, 	loss : 0.3033, 	accuracy : 0.9524
# epoch : 085, 	loss : 0.3077, 	accuracy : 0.9619
# epoch : 086, 	loss : 0.2957, 	accuracy : 0.9619
# epoch : 087, 	loss : 0.2926, 	accuracy : 0.9524
# epoch : 088, 	loss : 0.2998, 	accuracy : 0.9714
# epoch : 089, 	loss : 0.287, 	accuracy : 0.9619
# epoch : 090, 	loss : 0.2867, 	accuracy : 0.9524
# epoch : 091, 	loss : 0.2906, 	accuracy : 0.9619
# epoch : 092, 	loss : 0.2877, 	accuracy : 0.9524
# epoch : 093, 	loss : 0.2833, 	accuracy : 0.9619
# epoch : 094, 	loss : 0.2795, 	accuracy : 0.9619
# epoch : 095, 	loss : 0.2755, 	accuracy : 0.9524
# epoch : 096, 	loss : 0.28, 	accuracy : 0.9619
# epoch : 097, 	loss : 0.277, 	accuracy : 0.9524
# epoch : 098, 	loss : 0.2711, 	accuracy : 0.9714
# epoch : 099, 	loss : 0.2722, 	accuracy : 0.9429
# epoch : 100, 	loss : 0.2712, 	accuracy : 0.9524
# epoch : 101, 	loss : 0.2717, 	accuracy : 0.9524
# epoch : 102, 	loss : 0.2643, 	accuracy : 0.9619
# epoch : 103, 	loss : 0.2673, 	accuracy : 0.9524
# epoch : 104, 	loss : 0.2692, 	accuracy : 0.9714
# epoch : 105, 	loss : 0.264, 	accuracy : 0.9619
# epoch : 106, 	loss : 0.2594, 	accuracy : 0.9619
# epoch : 107, 	loss : 0.2608, 	accuracy : 0.9524
# epoch : 108, 	loss : 0.2563, 	accuracy : 0.9619
# epoch : 109, 	loss : 0.2562, 	accuracy : 0.9619
# epoch : 110, 	loss : 0.2551, 	accuracy : 0.9524
# epoch : 111, 	loss : 0.2525, 	accuracy : 0.9524
# epoch : 112, 	loss : 0.2522, 	accuracy : 0.9429
# epoch : 113, 	loss : 0.2456, 	accuracy : 0.9524
# epoch : 114, 	loss : 0.2512, 	accuracy : 0.9524
# epoch : 115, 	loss : 0.258, 	accuracy : 0.9619
# epoch : 116, 	loss : 0.2447, 	accuracy : 0.9524
# epoch : 117, 	loss : 0.2494, 	accuracy : 0.9524
# epoch : 118, 	loss : 0.2404, 	accuracy : 0.9524
# epoch : 119, 	loss : 0.2418, 	accuracy : 0.9429
# epoch : 120, 	loss : 0.2506, 	accuracy : 0.9524
# epoch : 121, 	loss : 0.2387, 	accuracy : 0.9619
# epoch : 122, 	loss : 0.2415, 	accuracy : 0.9524
# epoch : 123, 	loss : 0.2344, 	accuracy : 0.9619
# epoch : 124, 	loss : 0.2397, 	accuracy : 0.9524
# epoch : 125, 	loss : 0.2355, 	accuracy : 0.9619
# epoch : 126, 	loss : 0.2396, 	accuracy : 0.9714
# epoch : 127, 	loss : 0.2299, 	accuracy : 0.9619
# epoch : 128, 	loss : 0.2257, 	accuracy : 0.9524
# epoch : 129, 	loss : 0.2287, 	accuracy : 0.9714
# epoch : 130, 	loss : 0.2245, 	accuracy : 0.9524
# epoch : 131, 	loss : 0.2235, 	accuracy : 0.9524
# epoch : 132, 	loss : 0.2264, 	accuracy : 0.9619
# epoch : 133, 	loss : 0.2235, 	accuracy : 0.9524
# epoch : 134, 	loss : 0.225, 	accuracy : 0.9524
# epoch : 135, 	loss : 0.2189, 	accuracy : 0.9524
# epoch : 136, 	loss : 0.2193, 	accuracy : 0.9524
# epoch : 137, 	loss : 0.2227, 	accuracy : 0.9524
# epoch : 138, 	loss : 0.2218, 	accuracy : 0.9524
# epoch : 139, 	loss : 0.2225, 	accuracy : 0.9524
# epoch : 140, 	loss : 0.2188, 	accuracy : 0.9619
# epoch : 141, 	loss : 0.2117, 	accuracy : 0.9619
# epoch : 142, 	loss : 0.2185, 	accuracy : 0.9524
# epoch : 143, 	loss : 0.2111, 	accuracy : 0.9714
# epoch : 144, 	loss : 0.2107, 	accuracy : 0.9524
# epoch : 145, 	loss : 0.2133, 	accuracy : 0.9524
# epoch : 146, 	loss : 0.2098, 	accuracy : 0.9714
# epoch : 147, 	loss : 0.2102, 	accuracy : 0.9524
# epoch : 148, 	loss : 0.2079, 	accuracy : 0.9524
# epoch : 149, 	loss : 0.2141, 	accuracy : 0.9714
# epoch : 150, 	loss : 0.2039, 	accuracy : 0.9619
# epoch : 151, 	loss : 0.2081, 	accuracy : 0.9524
# epoch : 152, 	loss : 0.2047, 	accuracy : 0.9524
# epoch : 153, 	loss : 0.2024, 	accuracy : 0.9619
# epoch : 154, 	loss : 0.2016, 	accuracy : 0.9524
# epoch : 155, 	loss : 0.2017, 	accuracy : 0.9524
# epoch : 156, 	loss : 0.202, 	accuracy : 0.9714
# epoch : 157, 	loss : 0.1988, 	accuracy : 0.9524
# epoch : 158, 	loss : 0.2041, 	accuracy : 0.9619
# epoch : 159, 	loss : 0.1927, 	accuracy : 0.9524
# epoch : 160, 	loss : 0.1983, 	accuracy : 0.9619
# epoch : 161, 	loss : 0.1947, 	accuracy : 0.9524
# epoch : 162, 	loss : 0.1993, 	accuracy : 0.9524
# epoch : 163, 	loss : 0.1971, 	accuracy : 0.9714
# epoch : 164, 	loss : 0.1953, 	accuracy : 0.9524
# epoch : 165, 	loss : 0.1914, 	accuracy : 0.9524
# epoch : 166, 	loss : 0.1964, 	accuracy : 0.9524
# epoch : 167, 	loss : 0.1876, 	accuracy : 0.9524
# epoch : 168, 	loss : 0.1908, 	accuracy : 0.9524
# epoch : 169, 	loss : 0.1874, 	accuracy : 0.9714
# epoch : 170, 	loss : 0.1925, 	accuracy : 0.9714
# epoch : 171, 	loss : 0.189, 	accuracy : 0.9714
# epoch : 172, 	loss : 0.1855, 	accuracy : 0.9524
# epoch : 173, 	loss : 0.1919, 	accuracy : 0.9524
# epoch : 174, 	loss : 0.1842, 	accuracy : 0.981
# epoch : 175, 	loss : 0.18, 	accuracy : 0.9714
# epoch : 176, 	loss : 0.1772, 	accuracy : 0.9619
# epoch : 177, 	loss : 0.1857, 	accuracy : 0.9524
# epoch : 178, 	loss : 0.1831, 	accuracy : 0.9714
# epoch : 179, 	loss : 0.1845, 	accuracy : 0.9619
# epoch : 180, 	loss : 0.1765, 	accuracy : 0.9619
# epoch : 181, 	loss : 0.1761, 	accuracy : 0.9524
# epoch : 182, 	loss : 0.1794, 	accuracy : 0.9714
# epoch : 183, 	loss : 0.1757, 	accuracy : 0.9619
# epoch : 184, 	loss : 0.1752, 	accuracy : 0.9429
# epoch : 185, 	loss : 0.1746, 	accuracy : 0.9714
# epoch : 186, 	loss : 0.172, 	accuracy : 0.9524
# epoch : 187, 	loss : 0.1731, 	accuracy : 0.9619
# epoch : 188, 	loss : 0.1755, 	accuracy : 0.9714
# epoch : 189, 	loss : 0.1742, 	accuracy : 0.9619
# epoch : 190, 	loss : 0.1729, 	accuracy : 0.9619
# epoch : 191, 	loss : 0.1735, 	accuracy : 0.9619
# epoch : 192, 	loss : 0.1766, 	accuracy : 0.9714
# epoch : 193, 	loss : 0.1882, 	accuracy : 0.9619
# epoch : 194, 	loss : 0.168, 	accuracy : 0.9714
# epoch : 195, 	loss : 0.1731, 	accuracy : 0.9714
# epoch : 196, 	loss : 0.1717, 	accuracy : 0.9524
# epoch : 197, 	loss : 0.1672, 	accuracy : 0.9619
# epoch : 198, 	loss : 0.1648, 	accuracy : 0.9714
# epoch : 199, 	loss : 0.1774, 	accuracy : 0.9524
# epoch : 200, 	loss : 0.173, 	accuracy : 0.9619

# %%
#plot result

import matplotlib.pyplot as plt

plt.figure(figsize = (20, 5))
plt.subplots_adjust(wspace=0.2)

plt.subplot(1, 2, 1)
plt.title('$loss$',fontsize = 18)
plt.plot(losses)
plt.grid()
plt.xlabel('$epochs$',fontsize = 16)
plt.xticks(fontsize = 14)
plt.yticks(fontsize = 14)

plt.subplot(1, 2, 2)
plt.title('$accuracy$',fontsize = 18)
plt.plot(accuracies)
plt.grid()
plt.xlabel('$epochs$',fontsize = 16)
plt.xticks(fontsize = 14)
plt.yticks(fontsize = 14)

plt.show()

# %%
output = net(X_test)
_, predicted = torch.max(output, dim =1)
accuracy = round((predicted == y_test).sum().item()/len(y_test),4)

print('test_set accuracy : ', round(accuracy, 4))

# %% [markdown]
# ### Hidden layer 2개 더 생성한 모델
# - BatchNorm1d을 1번 더 진행, 나머지 조건은 동일하다.

# %%
class Net(nn.Module):

  def __init__(self):
    super(Net, self).__init__()

    self.layer1 = nn.Linear(4, 64)
    self.layer2 = nn.Linear(64, 32)
    self.layer3 = nn.Linear(32, 10)

    self.bn1 = nn.BatchNorm1d(64)
    self.bn2 = nn.BatchNorm1d(32)

    self.act = nn.ReLU()

  def forward(self, x):
    x = self.act(self.bn1(self.layer1(x)))
    x = self.act(self.bn2(self.layer2(x)))
    x = self.act(self.layer3(x))

    return x

# %%
net = Net()
print(net)

# %%
optimizer = optim.Adam(net.parameters(), lr=0.005)
criterion = nn.CrossEntropyLoss()
epochs = 200

# %%
losses = list()
accuracies = list()

for epoch in range(epochs):
    epoch_loss = 0
    epoch_accuracy = 0
    for X, y in train_loader:

        optimizer.zero_grad()

        output = net(X)

        loss = criterion(output, y)
        loss.backward()

        optimizer.step()

        _,predicted = torch.max(output, dim=1) 
    
        accuracy = (predicted ==y).sum().item()
        epoch_loss += loss.item()
        epoch_accuracy += accuracy

    epoch_loss /= len(train_loader)
    epoch_accuracy /= len(X_train)
    print('epoch : {}, \tloss : {}, \taccuracy : {}'.format(str(epoch+1).zfill(3),round(epoch_loss, 4),round(epoch_accuracy, 4)))

    losses.append(epoch_loss)
    accuracies.append(epoch_accuracy)

# %%
output = net(X_test)
_, predicted = torch.max(output, dim =1)
accuracy = round((predicted == y_test).sum().item()/len(y_test),4)

print('test_set accuracy : ', round(accuracy, 4))
