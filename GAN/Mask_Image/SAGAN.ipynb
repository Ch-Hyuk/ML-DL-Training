# %% [markdown]
# ### <b> SAGAN을 이용한 얼굴 마스크 이미지 생성 </b>
#
# * 마스크를 착용한 이미지와 마스크를 착용하지 않은 얼굴 이미지를 생성하는 <b>생성 모델</b>을 만듬.
# * 최종적으로 만들어진 이미지를 FID평가지표를 통해 평가

# %% [markdown]
# #### <b>(알아보기) 데이터셋 다운로드</b>
#
# * 실습을 위해 [<b>Face Mask Classification</b> 데이터셋](https://github.com/ndb796/Face-Mask-Classification-20000-Dataset)을 불러옵니다.
# * 데이터셋은 흑백(grayscale) 이미지로 구성됩니다.
# * GPU 가속기를 이용하기 위해 <b>[런타임]</b> - <b>[런타임 유형 변경]</b> - <b>[GPU]</b>를 선택합니다.
# * <b>학습 데이터셋</b>
#     * 마스크 착용(with mask): 9,000장
#     * 마스크 미착용(wihtout mask): 9,000장
# * <b>테스트 데이터셋</b>
#     * 마스크 착용(with mask): 1,000장
#     * 마스크 미착용(wihtout mask): 1,000장

# %%
# !git clone https://github.com/ndb796/Face-Mask-Classification-20000-Dataset

# %%
import os
import time
import matplotlib.pyplot as plt
from PIL import Image

import torch
import torch.nn as nn

from torchvision import datasets
import torchvision.transforms as transforms
from torchvision.utils import save_image

# %% [markdown]
# #### <b> 학습 이미지 시각화</b>
#
# * 학습할 이미지 중에서 원하는 이미지를 골라 시각화합니다.

# %%
# 마스크를 쓴 이미지 출력
image = Image.open('./Face-Mask-Classification-20000-Dataset/train/with_mask/with-mask-default-mask-seed0030.png')
print("이미지 크기:", image.size)

plt.imshow(image, cmap='gray')
plt.show()

# 마스크를 쓰지 않은 이미지 출력
image = Image.open('./Face-Mask-Classification-20000-Dataset/train/without_mask/seed0030.png')
print("이미지 크기:", image.size)

plt.imshow(image, cmap='gray')
plt.show()
# Out:
# 이미지 크기: (224, 224)
# 이미지 크기: (224, 224)

# %% [markdown]
# #### <b> 데이터셋 불러오기</b>
#
# * 학습할 이미지 크기: 1 X 64 X 64

# %%
transforms_train = transforms.Compose([
    transforms.Resize((64, 64)),
    transforms.Grayscale(1),
    transforms.ToTensor(),
    transforms.Normalize((0.5), (0.5)) # normalization
])

data_dir = './Face-Mask-Classification-20000-Dataset/'
train_dataset = datasets.ImageFolder(os.path.join(data_dir, 'train'), transforms_train)
train_dataloader = torch.utils.data.DataLoader(train_dataset, batch_size=64, shuffle=True, num_workers=2)
print('Train dataset size:', len(train_dataset))

class_names = train_dataset.classes
print('Class names:', class_names)
# Out:
# Train dataset size: 18000
# Class names: ['with_mask', 'without_mask']

# %% [markdown]
# #### <b>SAGAN 모델을 사용하여 이미지 생성</b>
#
# * 결과적으로 자신이 학습한 모델의 <b>최종 FID 점수(score)를 작성</b>
# * 마스크 착용 및 미착용 이미지를 <b>각각 1,000장씩 생성</b>하여 FID를 계산
# * 결과 이미지의 해상도는 1 X 64 X 64가 되어야 합니다.

# %%
class Self_Attention(nn.Module) :
    '''Self-Attention layer'''
    
    def __init__(self, in_dim) :
        super(Self_Attention, self).__init__()
        
        # 1x1의 합성곱 층을 활용한 점별 합성곱 준비
        self.query_conv = nn.Conv2d(in_channels=in_dim, out_channels=in_dim//8,
                                   kernel_size=1)
        self.key_conv = nn.Conv2d(in_channels=in_dim, out_channels=in_dim//8,
                                 kernel_size=1)
        self.value_conv = nn.Conv2d(in_channels=in_dim, out_channels=in_dim,
                                   kernel_size=1)
        
        # Attention Map을 작성할 때 규격화 소프트맥스
        self.softmax = nn.Softmax(dim=-2)
        
        # 원래 입력 x와 Self-Attention Map인 o를 더할 때 계수
        # output = x + gamma * o
        # 처음에는 gamma=0으로 학습시킨다.
        self.gamma = nn.Parameter(torch.zeros(1))
        
    def forward(self, x) :
        
        # 입력 변수
        X = x
        
        # 합성곱한 뒤 크기를 변형시킴. B, C', W, H->B, C', N으로
        proj_query = self.query_conv(X).view(X.shape[0], -1, X.shape[2]*X.shape[3]) 
        # 크기 : B, C', N
        proj_query = proj_query.permute(0, 2, 1) # 전치 조작
        proj_key = self.key_conv(X).view(X.shape[0], -1, X.shape[2] * X.shape[3]) 
        # 크기 : B, C', N
        
        # 곱셈
        S = torch.bmm(proj_query, proj_key) # bmm은 배치별 행렬곱
        
        # 규격화
        attention_map_T = self.softmax(S) # i행 방향의 합을 1로 하는 소프트맥스 함수
        attention_map = attention_map_T.permute(0, 2, 1) # 전치
        
        # Self-Attention Map 계산
        proj_value = self.value_conv(X).view(X.shape[0], -1, X.shape[2]*X.shape[3])
        o = torch.bmm(proj_value, attention_map.permute(0, 2, 1)) # Attention Map을 전치하여 곱함
        
        # Self-Attention Map의 텐서 크기를 X로 준비하여 출력
        o = o.view(X.shape[0], X.shape[1], X.shape[2], X.shape[3])
        out = x + self.gamma * o
        
        return out, attention_map

# %%
latent_dim = 100
n_classes = 2

# 생성자(Generator) 클래스 정의
class Generator(nn.Module):
    def __init__(self, z_dim=100, image_size=64) :
        super(Generator, self).__init__()
        self.label_embed = nn.Embedding(n_classes, n_classes)
        self.layer1 = nn.Sequential(
        # 스펙트럴 정규화 추가
        nn.utils.spectral_norm(nn.ConvTranspose2d(z_dim+2, image_size*8,
                                                 kernel_size=4, stride=1)),
        nn.BatchNorm2d(image_size*8),
        nn.LeakyReLU(0.2, inplace=True))
        
        self.layer2 = nn.Sequential(
        # 스펙트럴 정규화 추가
        nn.utils.spectral_norm(nn.ConvTranspose2d(image_size*8,
                                image_size*4, kernel_size=4, stride=2,
                                                 padding=1)),
                                nn.BatchNorm2d(image_size*4),
                                nn.LeakyReLU(0.2, inplace=True))
        
        self.layer3 = nn.Sequential(
        # 스펙트럴 정규화 추가
        nn.utils.spectral_norm(nn.ConvTranspose2d(image_size*4, image_size*2,
                                kernel_size=4, stride=2, padding=1)),
        
        nn.BatchNorm2d(image_size*2),
        nn.LeakyReLU(0.2, inplace=True))
        
        # Self-Attention 층 추가
        self.self_attention1 = Self_Attention(in_dim=image_size*2)
        
        self.layer4 = nn.Sequential(
        # 스펙트럴 정규화 추가
        nn.utils.spectral_norm(nn.ConvTranspose2d(image_size*2, image_size,
                                kernel_size=4, stride=2, padding=1)),
        nn.BatchNorm2d(image_size),
        nn.LeakyReLU(0.2, inplace=True))
        
        # Sself-Attention 층 추가
        self.self_attention2 = Self_Attention(in_dim=image_size)
        
        self.last = nn.Sequential(nn.ConvTranspose2d(image_size,
                                1, kernel_size=4, stride=2, padding=1),
                                 nn.Tanh())
        # 주의 ! 흑백 화상이므로 출력 채널은 하나 뿐이다
        
    def forward(self, noise, labels):
        embed = self.label_embed(labels)
        embed = embed.view(-1,n_classes, 1, 1)
        inputs = torch.cat((noise, embed), dim=1)
        out = self.layer1(inputs)
        out = self.layer2(out)
        out = self.layer3(out)        
        out, attention_map1 = self.self_attention1(out)
        out = self.layer4(out)
        out, attention_map2 = self.self_attention2(out)
        out = self.last(out)
        
        return out, attention_map1, attention_map2

# %%
class Discriminator(nn.Module) :
    
    def __init__(self, z_dim=100, image_size=64) :
        super(Discriminator, self).__init__()
        
        self.label_embed = nn.Embedding(n_classes, 1 * 64 * 64)
        
        self.layer1 = nn.Sequential(
                    #스펙트럴 정규화 추가
                    nn.utils.spectral_norm(nn.Conv2d(2, image_size, kernel_size=4,
                                                   stride=2, padding=1)),
                    nn.LeakyReLU(0.1, inplace=True))
                    # 흑백 화상이므로 출력 채널은 하나뿐이다.
            
        self.layer2 = nn.Sequential(
                    # 스펙트럴 정규화 추가
                    nn.utils.spectral_norm(nn.Conv2d(image_size, image_size*2, 
                                                    kernel_size=4, stride=2,
                                                    padding=1)),
                    nn.LeakyReLU(0.1, inplace=True))
        
        self.layer3 = nn.Sequential(
                    # 스펙트럴 정규화 추가
                    nn.utils.spectral_norm(nn.Conv2d(image_size*2, image_size*4, 
                                                    kernel_size=4, stride=2,
                                                    padding=1)),
                    nn.LeakyReLU(0.1, inplace=True))
            
        # Self-Attention 층 추가
        self.self_attention1 = Self_Attention(in_dim = image_size * 4)
        
        self.layer4= nn.Sequential(
                    # 스펙트럴 정규화 추가
                    nn.utils.spectral_norm(nn.Conv2d(image_size * 4, image_size * 8,
                                                    kernel_size=4, stride=2, padding=1)),
                    nn.LeakyReLU(0.1, inplace=True))
         
        
        # Self-Attention 층 추가
        self.self_attention2 = Self_Attention(in_dim=image_size*8)
        
        self.last = nn.Conv2d(image_size*8, 1, kernel_size=4, stride=1)
            
    
    def forward(self, img, labels) :
        embed = self.label_embed(labels).view((img.size(0), 1, 64, 64))
        inputs = torch.cat((img, embed), 1)
        out = self.layer1(inputs)
        out = self.layer2(out)
        out = self.layer3(out)            
        out, attention_map1 = self.self_attention1(out)
        out = self.layer4(out)
        out, attention_map2 = self.self_attention2(out)
        out = self.last(out)

        return out, attention_map1, attention_map2

# %%
#test printing
import matplotlib.pyplot as plt
# %matplotlib inline

G = Generator(z_dim=100, image_size=64)

input_z = torch.randn(1, 100)

input_z = input_z.view(input_z.size(0), input_z.size(1), 1, 1)

generated_labels = torch.randint(0, n_classes, (1,))
fake_images, attention_map1, attention_map2 = G(input_z, generated_labels)

img_transformed = fake_images[0][0].detach().numpy()
plt.imshow(img_transformed, 'gray')
plt.show()

# %%
# test printing

D = Discriminator(z_dim=100, image_size=64)

input_z = torch.randn(1, 100)
input_z = input_z.view(input_z.size(0), input_z.size(1), 1, 1)
generated_labels = torch.randint(0, n_classes, (1,))
fake_images, _, _ = G(input_z, generated_labels)

d_out, attention_map1, attention_map2 = D(fake_images, generated_labels)

print(nn.Sigmoid()(d_out))
# Out:
# tensor([[[[0.4424]]]], grad_fn=<SigmoidBackward0>)

# %%
# SAGAN의 학습 함수 구현

# 모델을 학습시키는 함수 작성
def train_model(G, D, dataloader, num_epochs) :
    
    # GPU 사용 여부 확인
    device= torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')
    print('사용 장치 :', device)
    
    # 최적화 기법 설정
    g_lr, d_lr = 0.0001, 0.0004
    beta1, beta2 = 0.0, 0.9
    g_optimizer = torch.optim.Adam(G.parameters(), g_lr, [beta1, beta2])
    d_optimizer = torch.optim.Adam(D.parameters(), d_lr, [beta1, beta2])
    
    # 오차함수 정의 -> 적대적 손실의 힌지 버전으로 변경
    # criterion = nn.BCEWithLogitsLoss(reduction='mean')
    
    # 파라미터 하드코딩
    z_dim = 100
    mini_batch_size=64
    
    # 네트워크를 GPU로
    G.to(device)
    D.to(device)
    
    G.train() # 모델을 훈련 모드로
    D.train() # 모델을 훈련 모드로
    
    # 네트워크가 어느 정도 고정되면 고속화
    torch.backends.cudnn.benchmark = True
    
    # 화상 매수
    num_train_imgs = len(dataloader.dataset)
    batch_size = dataloader.batch_size
    
    # 반복 카운터 설정
    iteration = 1
    logs = []
    
    # 에폭 루프
    for epoch in range(num_epochs) :
        
        # 개시 시간 저장
        t_epoch_start = time.time()
        epoch_g_loss = 0.0 # 에폭의 손실 합
        epoch_d_loss = 0.0 # 에폭의 손실 합
        
        print('-' * 20)
        print(f'Epoch {epoch}/{num_epochs}')
        print('-' * 20)
        print(' (train) ')
        
        # 데이터 로더에서 미니배치 씩 꺼내는 루프
        for data in dataloader :
            
            images = data[:][0]
            labels = data[:][1]
            
            # ------------------------
            # 1. discriminator 학습
            # ------------------------
            # 미니 배치 크기가 1이면 배치 정규화에서 오류가 발생하므로 피한다
            if images.size()[0] == 1 :
                continue
                
            # GPU를 사용할 수 있으면 GPU로 데이터를 보낸다
            images= images.to(device)
            labels= labels.to(device)
            
            # 정답 라벨과 가짜 라벨 작성
            # 에폭의 마지막 반복은 미니배치 수가 줄어듦
            mini_batch_size = images.size()[0]
            # label_real = torch.full((mini_batch_size,), 1).to(device)
            # label_fake = torch.full((mini_batch_size,), 0).to(device)    
            
            # 진짜 화상 판정
            d_out_real, _, _ = D(images, labels)
            
            # 가짜 화상을 생성하여 판정
            input_z = torch.randn(mini_batch_size , latent_dim).to(device)
            input_z = input_z.view(input_z.size(0), input_z.size(1), 1, 1)
            fake_images, _, _ = G(input_z, labels)
            d_out_fake, _, _ = D(fake_images, labels)
            
            # 오차 계산 --> 적대적 손실의 힌지 버전으로 변경
            # d_loss_real = criterion(d_out_real.view(-1), label_real)
            # d_loss_fake = criterion(d_out_fake.view(-1), label_fake)
            
            d_loss_real = torch.nn.ReLU()(1.0 - d_out_real).mean()
            # 오차 d_out_real이 1 이상에서 오차 0이 된다. d_out_real > 1에서
            # 1.0 - d_out_real이 음수이면 ReLU 로 0으로 한다.
            
            d_loss_fake = torch.nn.ReLU()(1.0 + d_out_fake).mean()
            # 오차 d_out_fake가 -1 이하이면 오차 0이 된다. d_out_fake < -1에서
            # 1.0 + dout_real이 음수이면 ReLU로 0으로 한다.
            
            d_loss = d_loss_real + d_loss_fake
            
            # 역전파
            g_optimizer.zero_grad()
            d_optimizer.zero_grad()
            
            d_loss.backward()
            d_optimizer.step()
            
            # ------------------------
            # 2. Generator 학습
            # ------------------------
            # 가짜 화상을 생성하여 판정
            input_z = torch.randn(mini_batch_size, z_dim).to(device)
            input_z = input_z.view(input_z.size(0), input_z.size(1), 1, 1)
            fake_images, _, _ = G(input_z, labels)
            d_out_fake, _, _ = D(fake_images, labels)
            
            # 오차 계산 --> 적대적 손실의 힌지 버전으로 변경
            #g_loss = criterion(d_out_fake.view(-1), label_real)
            g_loss = -d_out_fake.mean()
            
            # 역전파
            g_optimizer.zero_grad()
            d_optimizer.zero_grad()
            g_loss.backward()
            g_optimizer.step()
            
            # ------------------------
            # 3. 기록
            # ------------------------
            epoch_d_loss += d_loss.item()
            epoch_g_loss += g_loss.item()
            iteration += 1
            
        # 에폭의 phase 별 손실과 정답률
        t_epoch_finish = time.time()
        print('-' * 20)
        print(f'epoch {epoch} || epoch_D_Loss : {epoch_d_loss/batch_size:.4f} \ || Epoch_G_Loss : {epoch_g_loss/batch_size:.4f}')
        print(f'timer: {t_epoch_finish  - t_epoch_start:.4f}')
        t_epoch_start = time.time()
              
    return G, D

# %%
# 네트워크 초기화
def weights_init(m) :
    classname = m.__class__.__name__
    if classname.find('Conv') != -1 :
        # Conv2d와 ConvTranspose2d 초기화
        nn.init.normal_(m.weight.data, 0.0, 0.02)
        nn.init.constant_(m.bias.data, 0)
    elif classname.find('BatchNorm') != -1 :
        # BatchNorm2d 초기화
        nn.init.normal_(m.weight.data ,1.0, 0.02)
        nn.init.constant_(m.bias.data, 0)
    
# 초기화 실시
G.apply(weights_init)
D.apply(weights_init)

# %%
# 학습 및 검증 실행
num_epochs = 100
G_update, D_update = train_model(G, D, dataloader=train_dataloader, num_epochs=num_epochs)
# Out:
# 사용 장치 : cuda:0
# --------------------
# Epoch 0/50
# --------------------
#  (train)
# --------------------
# epoch 0 || epoch_D_Loss : 1.2924 \ || Epoch_G_Loss : 11.8111
# timer: 48.5879
# --------------------
# Epoch 1/50
# --------------------
#  (train)
# --------------------
# epoch 1 || epoch_D_Loss : 0.9393 \ || Epoch_G_Loss : 11.7165
# timer: 47.6728
# --------------------
# Epoch 2/50
# --------------------
#  (train)
# --------------------
# epoch 2 || epoch_D_Loss : 0.8571 \ || Epoch_G_Loss : 10.3773
# timer: 48.3257
# --------------------
# Epoch 3/50
# --------------------
#  (train)
# --------------------
# epoch 3 || epoch_D_Loss : 0.9001 \ || Epoch_G_Loss : 9.7548
# timer: 48.0491
# --------------------
# Epoch 4/50
# --------------------
#  (train)
# --------------------
# epoch 4 || epoch_D_Loss : 0.7519 \ || Epoch_G_Loss : 11.3622
# timer: 48.2193
# --------------------
# Epoch 5/50
# --------------------
#  (train)
# --------------------
# epoch 5 || epoch_D_Loss : 0.6034 \ || Epoch_G_Loss : 11.6557
# timer: 48.1156
# --------------------
# Epoch 6/50
# --------------------
#  (train)
# --------------------
# epoch 6 || epoch_D_Loss : 0.4787 \ || Epoch_G_Loss : 11.5672
# timer: 48.2257
# --------------------
# Epoch 7/50
# --------------------
#  (train)
# --------------------
# epoch 7 || epoch_D_Loss : 0.5843 \ || Epoch_G_Loss : 12.6008
# timer: 47.8284
# --------------------
# Epoch 8/50
# --------------------
#  (train)
# --------------------
# epoch 8 || epoch_D_Loss : 0.1473 \ || Epoch_G_Loss : 10.0325
# timer: 47.6275
# --------------------
# Epoch 9/50
# --------------------
#  (train)
# --------------------
# epoch 9 || epoch_D_Loss : 0.0009 \ || Epoch_G_Loss : 9.1323
# timer: 47.3528
# --------------------
# Epoch 10/50
# --------------------
#  (train)
# --------------------
# epoch 10 || epoch_D_Loss : 0.0011 \ || Epoch_G_Loss : 14.2772
# timer: 47.4239
# --------------------
# Epoch 11/50
# --------------------
#  (train)
# --------------------
# epoch 11 || epoch_D_Loss : 0.0000 \ || Epoch_G_Loss : 9.3246
# timer: 47.3994
# --------------------
# Epoch 12/50
# --------------------
#  (train)
# --------------------
# epoch 12 || epoch_D_Loss : 0.0004 \ || Epoch_G_Loss : 11.1218
# timer: 47.5425
# --------------------
# Epoch 13/50
# --------------------
#  (train)
# --------------------
# epoch 13 || epoch_D_Loss : 0.0000 \ || Epoch_G_Loss : 10.0170
# timer: 47.2244
# --------------------
# Epoch 14/50
# --------------------
#  (train)
# --------------------
# epoch 14 || epoch_D_Loss : 0.0000 \ || Epoch_G_Loss : 9.2271
# timer: 47.4349
# --------------------
# Epoch 15/50
# --------------------
#  (train)
# --------------------
# epoch 15 || epoch_D_Loss : 0.0000 \ || Epoch_G_Loss : 8.8369
# timer: 47.3385
# --------------------
# Epoch 16/50
# --------------------
#  (train)
# --------------------
# epoch 16 || epoch_D_Loss : 0.0000 \ || Epoch_G_Loss : 8.5752
# timer: 47.4520
# --------------------
# Epoch 17/50
# --------------------
#  (train)
# --------------------
# epoch 17 || epoch_D_Loss : 0.0000 \ || Epoch_G_Loss : 8.3868
# timer: 47.2010
# --------------------
# Epoch 18/50
# --------------------
#  (train)
# --------------------
# epoch 18 || epoch_D_Loss : 0.0000 \ || Epoch_G_Loss : 8.2333
# timer: 47.3911
# --------------------
# Epoch 19/50
# --------------------
#  (train)
# --------------------
# epoch 19 || epoch_D_Loss : 0.0000 \ || Epoch_G_Loss : 8.1193
# timer: 47.2121
# --------------------
# Epoch 20/50
# --------------------
#  (train)
# --------------------
# epoch 20 || epoch_D_Loss : 0.0000 \ || Epoch_G_Loss : 8.0358
# timer: 47.3076
# --------------------
# Epoch 21/50
# --------------------
#  (train)
# --------------------
# epoch 21 || epoch_D_Loss : 0.0000 \ || Epoch_G_Loss : 7.9734
# timer: 47.2808
# --------------------
# Epoch 22/50
# --------------------
#  (train)
# --------------------
# epoch 22 || epoch_D_Loss : 0.0000 \ || Epoch_G_Loss : 7.9155
# timer: 47.3518
# --------------------
# Epoch 23/50
# --------------------
#  (train)
# --------------------
# epoch 23 || epoch_D_Loss : 0.0000 \ || Epoch_G_Loss : 7.8709
# timer: 47.6376
# --------------------
# Epoch 24/50
# --------------------
#  (train)
# --------------------
# epoch 24 || epoch_D_Loss : 0.0000 \ || Epoch_G_Loss : 7.8385
# timer: 47.3188
# --------------------
# Epoch 25/50
# --------------------
#  (train)
# --------------------
# epoch 25 || epoch_D_Loss : 0.0000 \ || Epoch_G_Loss : 7.8071
# timer: 47.5304
# --------------------
# Epoch 26/50
# --------------------
#  (train)
# --------------------
# epoch 26 || epoch_D_Loss : 0.0000 \ || Epoch_G_Loss : 7.7815
# timer: 47.1499
# --------------------
# Epoch 27/50
# --------------------
#  (train)
# --------------------
# epoch 27 || epoch_D_Loss : 0.0000 \ || Epoch_G_Loss : 7.7566
# timer: 47.4836
# --------------------
# Epoch 28/50
# --------------------
#  (train)
# --------------------
# epoch 28 || epoch_D_Loss : 0.0000 \ || Epoch_G_Loss : 7.7326
# timer: 47.1938
# --------------------
# Epoch 29/50
# --------------------
#  (train)
# --------------------
# epoch 29 || epoch_D_Loss : 0.0000 \ || Epoch_G_Loss : 7.7101
# timer: 47.3690
# --------------------
# Epoch 30/50
# --------------------
#  (train)
# --------------------
# epoch 30 || epoch_D_Loss : 0.0000 \ || Epoch_G_Loss : 7.6939
# timer: 47.3346
# --------------------
# Epoch 31/50
# --------------------
#  (train)
# --------------------
# epoch 31 || epoch_D_Loss : 0.0000 \ || Epoch_G_Loss : 7.6810
# timer: 47.4145
# --------------------
# Epoch 32/50
# --------------------
#  (train)
# --------------------
# epoch 32 || epoch_D_Loss : 0.0000 \ || Epoch_G_Loss : 7.6680
# timer: 47.3288
# --------------------
# Epoch 33/50
# --------------------
#  (train)
# --------------------
# epoch 33 || epoch_D_Loss : 0.0000 \ || Epoch_G_Loss : 7.6529
# timer: 47.4435
# --------------------
# Epoch 34/50
# --------------------
#  (train)
# --------------------
# epoch 34 || epoch_D_Loss : 0.0000 \ || Epoch_G_Loss : 7.6414
# timer: 47.2926
# --------------------
# Epoch 35/50
# --------------------
#  (train)
# --------------------
# epoch 35 || epoch_D_Loss : 0.0000 \ || Epoch_G_Loss : 7.6342
# timer: 47.6234
# --------------------
# Epoch 36/50
# --------------------
#  (train)
# --------------------
# epoch 36 || epoch_D_Loss : 0.0000 \ || Epoch_G_Loss : 7.6261
# timer: 47.4958
# --------------------
# Epoch 37/50
# --------------------
#  (train)
# --------------------
# epoch 37 || epoch_D_Loss : 0.0000 \ || Epoch_G_Loss : 7.6188
# timer: 47.3942
# --------------------
# Epoch 38/50
# --------------------
#  (train)
# --------------------
# epoch 38 || epoch_D_Loss : 0.0000 \ || Epoch_G_Loss : 7.6113
# timer: 47.2495
# --------------------
# Epoch 39/50
# --------------------
#  (train)
# --------------------
# epoch 39 || epoch_D_Loss : 0.0000 \ || Epoch_G_Loss : 7.6047
# timer: 47.3468
# --------------------
# Epoch 40/50
# --------------------
#  (train)
# --------------------
# epoch 40 || epoch_D_Loss : 0.0000 \ || Epoch_G_Loss : 7.5997
# timer: 47.2899
# --------------------
# Epoch 41/50
# --------------------
#  (train)
# --------------------
# epoch 41 || epoch_D_Loss : 0.0000 \ || Epoch_G_Loss : 7.5941
# timer: 47.4292
# --------------------
# Epoch 42/50
# --------------------
#  (train)
# --------------------
# epoch 42 || epoch_D_Loss : 0.0000 \ || Epoch_G_Loss : 7.5916
# timer: 47.2337
# --------------------
# Epoch 43/50
# --------------------
#  (train)
# --------------------
# epoch 43 || epoch_D_Loss : 0.0000 \ || Epoch_G_Loss : 7.5863
# timer: 47.3407
# --------------------
# Epoch 44/50
# --------------------
#  (train)
# --------------------
# epoch 44 || epoch_D_Loss : 0.0000 \ || Epoch_G_Loss : 7.5838
# timer: 47.3033
# --------------------
# Epoch 45/50
# --------------------
#  (train)
# --------------------
# epoch 45 || epoch_D_Loss : 0.0000 \ || Epoch_G_Loss : 7.5811
# timer: 47.4802
# --------------------
# Epoch 46/50
# --------------------
#  (train)
# --------------------
# epoch 46 || epoch_D_Loss : 0.0000 \ || Epoch_G_Loss : 7.5802
# timer: 47.2421
# --------------------
# Epoch 47/50
# --------------------
#  (train)
# --------------------
# epoch 47 || epoch_D_Loss : 0.0000 \ || Epoch_G_Loss : 7.5751
# timer: 47.6236
# --------------------
# Epoch 48/50
# --------------------
#  (train)
# --------------------
# epoch 48 || epoch_D_Loss : 0.0000 \ || Epoch_G_Loss : 7.5725
# timer: 47.2107
# --------------------
# Epoch 49/50
# --------------------
#  (train)
# --------------------
# epoch 49 || epoch_D_Loss : 0.0000 \ || Epoch_G_Loss : 7.5710
# timer: 47.4822

# %%
#test printing
import matplotlib.pyplot as plt
# %matplotlib inline

device= torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')

input_z = torch.randn(1, 100).to(device)

input_z = input_z.view(input_z.size(0), input_z.size(1), 1, 1)

generated_labels = torch.randint(0, n_classes, (1,)).to(device)
fake_images, attention_map1, attention_map2 = G_update(input_z, generated_labels)

img_transformed = fake_images[0][0].cpu().detach().numpy()
plt.imshow(img_transformed, 'gray')
plt.show()

# %% [markdown]
# ### 이미지 10 * 100개의 마스크 쓴 얼굴, 마스크 쓰지 않은 얼굴 생성

# %%
# !mkdir -p ./results/simple/with_mask
# !mkdir -p ./results/simple/without_mask
from IPython.display import Image as Display
# 마스크를 착용한 총 10 * 100개의 얼굴 이미지를 생성
for i in range(10):
    # 랜덤 노이즈(noise) 및 랜덤 레이블(label) 샘플링
    input_z = torch.randn(100, 100).to(device)
    input_z = input_z.view(input_z.size(0), input_z.size(1), 1, 1)
    generated_labels = torch.zeros(100,).to(device)
    generated_labels = generated_labels.int()
    # 이미지 생성
    generated_imgs, _, _ = G_update(input_z, generated_labels)
    for j in range(100):
        save_image(generated_imgs.data[j], f'./results/simple/with_mask/{i * 100 + j}.png', normalize=True)
# 마스크를 착용한 총 10 * 100개의 얼굴 이미지를 생성
for i in range(10):
    input_z = torch.randn(100, 100).to(device)
    input_z = input_z.view(input_z.size(0), input_z.size(1), 1, 1)
    generated_labels = torch.ones(100,).to(device)
    generated_labels = generated_labels.int()
    generated_imgs, _, _ = G_update(input_z, generated_labels)
    for j in range(100):
        save_image(generated_imgs.data[j], f'./results/simple/without_mask/{i * 100 + j}.png', normalize=True)

# %% [markdown]
# * 캐글에서 로컬 파일로 옮기기 위한 ZIP파일 생성

# %%
# !zip -r output.zip ./results/simple

# %%
# 생성 화상과 훈련 데이터 시각화
# 이 셀은 괜찮은 느낌의 화상이 생성될 때까지 몇 번 재실행한다.
device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')

# 입력 난수 생성
batch_size = 64
z_dim = 102
fixed_z = torch.randn(batch_size, z_dim)
fixed_z = fixed_z.view(fixed_z.size(0), fixed_z.size(1), 1, 1)

# 화상 생성
G_update.eval()
fake_images, am1, am2 = G_update(fixed_z.to(device))

# 훈련 데이터
batch_iterator = iter(train_dataloader) # 반복자로 변환
images = next(batch_iterator) # 첫 번째 요소를 꺼냄

# 출력
fig = plt.figure(figsize=(15, 6))

for i in range(0, 5) :
    # 상단에 훈련 데이터 표시
    plt.subplot(2, 5, i+1)
    plt.imshow(images[i][0].cpu().detach().numpy(), 'gray')
    
    # 하단에 생성 데이터 표시
    plt.subplot(2, 5, 5+i+1)
    plt.imshow(fake_images[i][0].cpu().detach().numpy(), 'gray')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[23], line 13
#      11 # 화상 생성
#      12 G_update.eval()
# ---> 13 fake_images, am1, am2 = G_update(fixed_z.to(device))
#      15 # 훈련 데이터
#      16 batch_iterator = iter(train_dataloader) # 반복자로 변환
#
# File /opt/conda/lib/python3.10/site-packages/torch/nn/modules/module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# TypeError: Generator.forward() missing 1 required positional argument: 'labels'

# %%
# Attention Map 출력
fig = plt.figure(figsize=(15, 6))
for i in range(0, 5) :
    
    # 하단에 생성한 화상 데이터 표시
    plt.subplot(2, 5, i+1)
    plt.imshow(fake_images[i][0].cpu().detach().numpy(), 'gray')
    
    # 하단에 Attention Map 1 화상 중앙의 픽셀 데이터 표시
    plt.subplot(2, 5, 5+i+1) 
    am = am1[i].view(16, 16, 16, 16)
    am = am[7][7] # 중앙에 주목
    plt.imshow(am.cpu().detach().numpy(), 'Reds')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[24], line 11
#       9 # 하단에 Attention Map 1 화상 중앙의 픽셀 데이터 표시
#      10 plt.subplot(2, 5, 5+i+1)
# ---> 11 am = am1[i].view(16, 16, 16, 16)
#      12 am = am[7][7] # 중앙에 주목
#      13 plt.imshow(am.cpu().detach().numpy(), 'Reds')
#
# NameError: name 'am1' is not defined

# %% [markdown]
# * FID평가지표를 통한 평가 확인

# %%
# !git clone https://github.com/hukkelas/pytorch-frechet-inception-distance
# Out:
# Cloning into 'pytorch-frechet-inception-distance'...
# remote: Enumerating objects: 22, done.
# remote: Total 22 (delta 0), reused 0 (delta 0), pack-reused 22
# Receiving objects: 100% (22/22), 12.21 KiB | 833.00 KiB/s, done.
# Resolving deltas: 100% (7/7), done.

# %% [markdown]
# - without_mask의 FID 평가지표

# %%
# 평가 수행
# !python ./pytorch-frechet-inception-distance/fid.py --path1 ./results/simple/without_mask --path2 ./Face-Mask-Classification-20000-Dataset/test/without_mask --batch-size 32
# Out:
# Looking for images in ./results/simple/without_mask/*.png
# Looking for images in ./results/simple/without_mask/*.jpg
# Looking for images in ./Face-Mask-Classification-20000-Dataset/test/without_mask/*.png
# Looking for images in ./Face-Mask-Classification-20000-Dataset/test/without_mask/*.jpg
# /opt/conda/lib/python3.10/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=Inception_V3_Weights.IMAGENET1K_V1`. You can also use `weights=Inception_V3_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/inception_v3_google-0cc3c7bd.pth" to /root/.cache/torch/hub/checkpoints/inception_v3_google-0cc3c7bd.pth
# 100%|████████████████████████████████████████| 104M/104M [00:01<00:00, 71.5MB/s]
# 480.5771349412143

# %% [markdown]
# - with_mask의 FID평가지표

# %%
# 평가 수행
# !python ./pytorch-frechet-inception-distance/fid.py --path1 ./results/simple/with_mask --path2 ./Face-Mask-Classification-20000-Dataset/test/with_mask --batch-size 32
# Out:
# Looking for images in ./results/simple/with_mask/*.png
# Looking for images in ./results/simple/with_mask/*.jpg
# Looking for images in ./Face-Mask-Classification-20000-Dataset/test/with_mask/*.png
# Looking for images in ./Face-Mask-Classification-20000-Dataset/test/with_mask/*.jpg
# /opt/conda/lib/python3.10/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=Inception_V3_Weights.IMAGENET1K_V1`. You can also use `weights=Inception_V3_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# 422.28078396494726

# %%
# ./results/custom/ 폴더의 모든 파일을 results.zip라는 이름으로 압축
# !zip ./results.zip -r ./results/simple/*
# Out:
#   adding: results/simple/with_mask/ (stored 0%)
#   adding: results/simple/with_mask/850.png (deflated 8%)
#   adding: results/simple/with_mask/518.png (deflated 8%)
#   adding: results/simple/with_mask/240.png (deflated 9%)
#   adding: results/simple/with_mask/446.png (deflated 8%)
#   adding: results/simple/with_mask/325.png (deflated 9%)
#   adding: results/simple/with_mask/19.png (deflated 9%)
#   adding: results/simple/with_mask/171.png (deflated 8%)
#   adding: results/simple/with_mask/278.png (deflated 9%)
#   adding: results/simple/with_mask/678.png (deflated 8%)
#   adding: results/simple/with_mask/654.png (deflated 9%)
#   adding: results/simple/with_mask/667.png (deflated 8%)
#   adding: results/simple/with_mask/907.png (deflated 8%)
#   adding: results/simple/with_mask/594.png (deflated 9%)
#   adding: results/simple/with_mask/747.png (deflated 9%)
#   adding: results/simple/with_mask/14.png (deflated 8%)
#   adding: results/simple/with_mask/441.png (deflated 9%)
#   adding: results/simple/with_mask/528.png (deflated 8%)
#   adding: results/simple/with_mask/986.png (deflated 8%)
#   adding: results/simple/with_mask/634.png (deflated 8%)
#   adding: results/simple/with_mask/288.png (deflated 8%)
#   adding: results/simple/with_mask/611.png (deflated 8%)
#   adding: results/simple/with_mask/323.png (deflated 8%)
#   adding: results/simple/with_mask/49.png (deflated 9%)
#   adding: results/simple/with_mask/677.png (deflated 9%)
#   adding: results/simple/with_mask/772.png (deflated 8%)
#   adding: results/simple/with_mask/121.png (deflated 9%)
#   adding: results/simple/with_mask/566.png (deflated 8%)
#   adding: results/simple/with_mask/701.png (deflated 8%)
#   adding: results/simple/with_mask/18.png (deflated 9%)
#   adding: results/simple/with_mask/987.png (deflated 9%)
#   adding: results/simple/with_mask/174.png (deflated 8%)
#   adding: results/simple/with_mask/420.png (deflated 9%)
#   adding: results/simple/with_mask/713.png (deflated 8%)
#   adding: results/simple/with_mask/33.png (deflated 9%)
#   adding: results/simple/with_mask/651.png (deflated 8%)
#   adding: results/simple/with_mask/869.png (deflated 8%)
#   adding: results/simple/with_mask/586.png (deflated 9%)
#   adding: results/simple/with_mask/536.png (deflated 9%)
#   adding: results/simple/with_mask/422.png (deflated 8%)
#   adding: results/simple/with_mask/127.png (deflated 9%)
#   adding: results/simple/with_mask/2.png (deflated 9%)
#   adding: results/simple/with_mask/85.png (deflated 8%)
#   adding: results/simple/with_mask/6.png (deflated 8%)
#   adding: results/simple/with_mask/556.png (deflated 8%)
#   adding: results/simple/with_mask/28.png (deflated 9%)
#   adding: results/simple/with_mask/767.png (deflated 8%)
#   adding: results/simple/with_mask/355.png (deflated 8%)
#   adding: results/simple/with_mask/239.png (deflated 8%)
#   adding: results/simple/with_mask/159.png (deflated 9%)
#   adding: results/simple/with_mask/379.png (deflated 8%)
#   adding: results/simple/with_mask/0.png (deflated 9%)
#   adding: results/simple/with_mask/707.png (deflated 8%)
#   adding: results/simple/with_mask/527.png (deflated 8%)
#   adding: results/simple/with_mask/874.png (deflated 9%)
#   adding: results/simple/with_mask/698.png (deflated 8%)
#   adding: results/simple/with_mask/478.png (deflated 9%)
#   adding: results/simple/with_mask/839.png (deflated 8%)
#   adding: results/simple/with_mask/382.png (deflated 9%)
#   adding: results/simple/with_mask/636.png (deflated 9%)
#   adding: results/simple/with_mask/642.png (deflated 8%)
#   adding: results/simple/with_mask/977.png (deflated 9%)
#   adding: results/simple/with_mask/886.png (deflated 8%)
#   adding: results/simple/with_mask/888.png (deflated 9%)
#   adding: results/simple/with_mask/401.png (deflated 8%)
#   adding: results/simple/with_mask/836.png (deflated 8%)
#   adding: results/simple/with_mask/847.png (deflated 8%)
#   adding: results/simple/with_mask/226.png (deflated 8%)
#   adding: results/simple/with_mask/688.png (deflated 9%)
#   adding: results/simple/with_mask/380.png (deflated 8%)
#   adding: results/simple/with_mask/616.png (deflated 8%)
#   adding: results/simple/with_mask/63.png (deflated 8%)
#   adding: results/simple/with_mask/128.png (deflated 9%)
#   adding: results/simple/with_mask/660.png (deflated 8%)
#   adding: results/simple/with_mask/571.png (deflated 9%)
#   adding: results/simple/with_mask/470.png (deflated 9%)
#   adding: results/simple/with_mask/623.png (deflated 9%)
#   adding: results/simple/with_mask/578.png (deflated 8%)
#   adding: results/simple/with_mask/574.png (deflated 8%)
#   adding: results/simple/with_mask/499.png (deflated 8%)
#   adding: results/simple/with_mask/64.png (deflated 9%)
#   adding: results/simple/with_mask/31.png (deflated 9%)
#   adding: results/simple/with_mask/965.png (deflated 9%)
#   adding: results/simple/with_mask/158.png (deflated 8%)
#   adding: results/simple/with_mask/638.png (deflated 8%)
#   adding: results/simple/with_mask/329.png (deflated 8%)
#   adding: results/simple/with_mask/754.png (deflated 9%)
#   adding: results/simple/with_mask/700.png (deflated 8%)
#   adding: results/simple/with_mask/486.png (deflated 8%)
#   adding: results/simple/with_mask/391.png (deflated 8%)
#   adding: results/simple/with_mask/924.png (deflated 8%)
#   adding: results/simple/with_mask/398.png (deflated 8%)
#   adding: results/simple/with_mask/617.png (deflated 9%)
#   adding: results/simple/with_mask/192.png (deflated 8%)
#   adding: results/simple/with_mask/891.png (deflated 9%)
#   adding: results/simple/with_mask/541.png (deflated 8%)
#   adding: results/simple/with_mask/801.png (deflated 9%)
#   adding: results/simple/with_mask/973.png (deflated 9%)
#   adding: results/simple/with_mask/685.png (deflated 9%)
#   adding: results/simple/with_mask/605.png (deflated 8%)
#   adding: results/simple/with_mask/508.png (deflated 8%)
#   adding: results/simple/with_mask/893.png (deflated 9%)
#   adding: results/simple/with_mask/521.png (deflated 9%)
#   adding: results/simple/with_mask/426.png (deflated 8%)
#   adding: results/simple/with_mask/286.png (deflated 8%)
#   adding: results/simple/with_mask/539.png (deflated 8%)
#   adding: results/simple/with_mask/885.png (deflated 9%)
#   adding: results/simple/with_mask/780.png (deflated 9%)
#   adding: results/simple/with_mask/287.png (deflated 9%)
#   adding: results/simple/with_mask/52.png (deflated 8%)
#   adding: results/simple/with_mask/210.png (deflated 8%)
#   adding: results/simple/with_mask/540.png (deflated 8%)
#   adding: results/simple/with_mask/492.png (deflated 8%)
#   adding: results/simple/with_mask/50.png (deflated 8%)
#   adding: results/simple/with_mask/374.png (deflated 8%)
#   adding: results/simple/with_mask/81.png (deflated 8%)
#   adding: results/simple/with_mask/622.png (deflated 8%)
#   adding: results/simple/with_mask/233.png (deflated 9%)
#   adding: results/simple/with_mask/162.png (deflated 9%)
#   adding: results/simple/with_mask/872.png (deflated 8%)
#   adding: results/simple/with_mask/351.png (deflated 8%)
#   adding: results/simple/with_mask/892.png (deflated 9%)
#   adding: results/simple/with_mask/47.png (deflated 9%)
#   adding: results/simple/with_mask/856.png (deflated 8%)
#   adding: results/simple/with_mask/272.png (deflated 9%)
#   adding: results/simple/with_mask/9.png (deflated 8%)
#   adding: results/simple/with_mask/937.png (deflated 9%)
#   adding: results/simple/with_mask/816.png (deflated 8%)
#   adding: results/simple/with_mask/953.png (deflated 9%)
#   adding: results/simple/with_mask/271.png (deflated 8%)
#   adding: results/simple/with_mask/405.png (deflated 9%)
#   adding: results/simple/with_mask/230.png (deflated 8%)
#   adding: results/simple/with_mask/652.png (deflated 9%)
#   adding: results/simple/with_mask/709.png (deflated 8%)
#   adding: results/simple/with_mask/905.png (deflated 9%)
#   adding: results/simple/with_mask/526.png (deflated 9%)
#   adding: results/simple/with_mask/661.png (deflated 9%)
#   adding: results/simple/with_mask/132.png (deflated 8%)
#   adding: results/simple/with_mask/43.png (deflated 8%)
#   adding: results/simple/with_mask/88.png (deflated 8%)
#   adding: results/simple/with_mask/502.png (deflated 9%)
#   adding: results/simple/with_mask/310.png (deflated 9%)
#   adding: results/simple/with_mask/250.png (deflated 9%)
#   adding: results/simple/with_mask/279.png (deflated 9%)
#   adding: results/simple/with_mask/956.png (deflated 8%)
#   adding: results/simple/with_mask/79.png (deflated 9%)
#   adding: results/simple/with_mask/485.png (deflated 9%)
#   adding: results/simple/with_mask/141.png (deflated 9%)
#   adding: results/simple/with_mask/773.png (deflated 9%)
#   adding: results/simple/with_mask/115.png (deflated 9%)
#   adding: results/simple/with_mask/922.png (deflated 9%)
#   adding: results/simple/with_mask/791.png (deflated 9%)
#   adding: results/simple/with_mask/861.png (deflated 9%)
#   adding: results/simple/with_mask/938.png (deflated 9%)
#   adding: results/simple/with_mask/71.png (deflated 9%)
#   adding: results/simple/with_mask/185.png (deflated 9%)
#   adding: results/simple/with_mask/161.png (deflated 9%)
#   adding: results/simple/with_mask/990.png (deflated 8%)
#   adding: results/simple/with_mask/479.png (deflated 9%)
#   adding: results/simple/with_mask/928.png (deflated 9%)
#   adding: results/simple/with_mask/538.png (deflated 9%)
#   adding: results/simple/with_mask/845.png (deflated 9%)
#   adding: results/simple/with_mask/152.png (deflated 8%)
#   adding: results/simple/with_mask/165.png (deflated 8%)
#   adding: results/simple/with_mask/130.png (deflated 9%)
#   adding: results/simple/with_mask/720.png (deflated 8%)
#   adding: results/simple/with_mask/964.png (deflated 9%)
#   adding: results/simple/with_mask/3.png (deflated 8%)
#   adding: results/simple/with_mask/378.png (deflated 8%)
#   adding: results/simple/with_mask/177.png (deflated 9%)
#   adding: results/simple/with_mask/341.png (deflated 9%)
#   adding: results/simple/with_mask/231.png (deflated 9%)
#   adding: results/simple/with_mask/411.png (deflated 8%)
#   adding: results/simple/with_mask/798.png (deflated 8%)
#   adding: results/simple/with_mask/881.png (deflated 8%)
#   adding: results/simple/with_mask/774.png (deflated 8%)
#   adding: results/simple/with_mask/48.png (deflated 8%)
#   adding: results/simple/with_mask/221.png (deflated 8%)
#   adding: results/simple/with_mask/412.png (deflated 9%)
#   adding: results/simple/with_mask/968.png (deflated 9%)
#   adding: results/simple/with_mask/606.png (deflated 9%)
#   adding: results/simple/with_mask/595.png (deflated 9%)
#   adding: results/simple/with_mask/184.png (deflated 8%)
#   adding: results/simple/with_mask/285.png (deflated 9%)
#   adding: results/simple/with_mask/867.png (deflated 9%)
#   adding: results/simple/with_mask/729.png (deflated 8%)
#   adding: results/simple/with_mask/670.png (deflated 8%)
#   adding: results/simple/with_mask/941.png (deflated 8%)
#   adding: results/simple/with_mask/101.png (deflated 9%)
#   adding: results/simple/with_mask/778.png (deflated 8%)
#   adding: results/simple/with_mask/249.png (deflated 9%)
#   adding: results/simple/with_mask/961.png (deflated 8%)
#   adding: results/simple/with_mask/243.png (deflated 8%)
#   adding: results/simple/with_mask/844.png (deflated 9%)
#   adding: results/simple/with_mask/802.png (deflated 9%)
#   adding: results/simple/with_mask/647.png (deflated 8%)
#   adding: results/simple/with_mask/548.png (deflated 9%)
#   adding: results/simple/with_mask/755.png (deflated 8%)
#   adding: results/simple/with_mask/788.png (deflated 9%)
#   adding: results/simple/with_mask/25.png (deflated 8%)
#   adding: results/simple/with_mask/342.png (deflated 8%)
#   adding: results/simple/with_mask/637.png (deflated 9%)
#   adding: results/simple/with_mask/111.png (deflated 9%)
#   adding: results/simple/with_mask/708.png (deflated 8%)
#   adding: results/simple/with_mask/109.png (deflated 9%)
#   adding: results/simple/with_mask/710.png (deflated 8%)
#   adding: results/simple/with_mask/969.png (deflated 8%)
#   adding: results/simple/with_mask/482.png (deflated 8%)
#   adding: results/simple/with_mask/613.png (deflated 8%)
#   adding: results/simple/with_mask/976.png (deflated 9%)
#   adding: results/simple/with_mask/61.png (deflated 8%)
#   adding: results/simple/with_mask/666.png (deflated 8%)
#   adding: results/simple/with_mask/837.png (deflated 8%)
#   adding: results/simple/with_mask/160.png (deflated 9%)
#   adding: results/simple/with_mask/223.png (deflated 9%)
#   adding: results/simple/with_mask/245.png (deflated 8%)
#   adding: results/simple/with_mask/997.png (deflated 8%)
#   adding: results/simple/with_mask/4.png (deflated 9%)
#   adding: results/simple/with_mask/530.png (deflated 9%)
#   adding: results/simple/with_mask/60.png (deflated 9%)
#   adding: results/simple/with_mask/75.png (deflated 9%)
#   adding: results/simple/with_mask/312.png (deflated 9%)
#   adding: results/simple/with_mask/474.png (deflated 8%)
#   adding: results/simple/with_mask/741.png (deflated 8%)
#   adding: results/simple/with_mask/302.png (deflated 8%)
#   adding: results/simple/with_mask/204.png (deflated 9%)
#   adding: results/simple/with_mask/455.png (deflated 8%)
#   adding: results/simple/with_mask/943.png (deflated 8%)
#   adding: results/simple/with_mask/225.png (deflated 9%)
#   adding: results/simple/with_mask/674.png (deflated 8%)
#   adding: results/simple/with_mask/467.png (deflated 9%)
#   adding: results/simple/with_mask/476.png (deflated 8%)
#   adding: results/simple/with_mask/254.png (deflated 9%)
#   adding: results/simple/with_mask/102.png (deflated 8%)
#   adding: results/simple/with_mask/746.png (deflated 8%)
#   adding: results/simple/with_mask/681.png (deflated 9%)
#   adding: results/simple/with_mask/74.png (deflated 9%)
#   adding: results/simple/with_mask/761.png (deflated 8%)
#   adding: results/simple/with_mask/884.png (deflated 8%)
#   adding: results/simple/with_mask/17.png (deflated 9%)
#   adding: results/simple/with_mask/473.png (deflated 9%)
#   adding: results/simple/with_mask/468.png (deflated 8%)
#   adding: results/simple/with_mask/333.png (deflated 9%)
#   adding: results/simple/with_mask/689.png (deflated 9%)
#   adding: results/simple/with_mask/360.png (deflated 8%)
#   adding: results/simple/with_mask/371.png (deflated 8%)
#   adding: results/simple/with_mask/481.png (deflated 8%)
#   adding: results/simple/with_mask/264.png (deflated 8%)
#   adding: results/simple/with_mask/42.png (deflated 9%)
#   adding: results/simple/with_mask/407.png (deflated 9%)
#   adding: results/simple/with_mask/362.png (deflated 9%)
#   adding: results/simple/with_mask/783.png (deflated 9%)
#   adding: results/simple/with_mask/212.png (deflated 9%)
#   adding: results/simple/with_mask/649.png (deflated 8%)
#   adding: results/simple/with_mask/615.png (deflated 9%)
#   adding: results/simple/with_mask/514.png (deflated 8%)
#   adding: results/simple/with_mask/437.png (deflated 9%)
#   adding: results/simple/with_mask/381.png (deflated 9%)
#   adding: results/simple/with_mask/724.png (deflated 8%)
#   adding: results/simple/with_mask/643.png (deflated 9%)
#   adding: results/simple/with_mask/895.png (deflated 9%)
#   adding: results/simple/with_mask/429.png (deflated 8%)
#   adding: results/simple/with_mask/242.png (deflated 9%)
#   adding: results/simple/with_mask/814.png (deflated 8%)
#   adding: results/simple/with_mask/863.png (deflated 8%)
#   adding: results/simple/with_mask/926.png (deflated 9%)
#   adding: results/simple/with_mask/138.png (deflated 9%)
#   adding: results/simple/with_mask/370.png (deflated 8%)
#   adding: results/simple/with_mask/21.png (deflated 9%)
#   adding: results/simple/with_mask/404.png (deflated 9%)
#   adding: results/simple/with_mask/954.png (deflated 8%)
#   adding: results/simple/with_mask/687.png (deflated 8%)
#   adding: results/simple/with_mask/646.png (deflated 8%)
#   adding: results/simple/with_mask/313.png (deflated 9%)
#   adding: results/simple/with_mask/547.png (deflated 9%)
#   adding: results/simple/with_mask/903.png (deflated 9%)
#   adding: results/simple/with_mask/806.png (deflated 9%)
#   adding: results/simple/with_mask/591.png (deflated 8%)
#   adding: results/simple/with_mask/317.png (deflated 9%)
#   adding: results/simple/with_mask/756.png (deflated 9%)
#   adding: results/simple/with_mask/745.png (deflated 8%)
#   adding: results/simple/with_mask/393.png (deflated 8%)
#   adding: results/simple/with_mask/983.png (deflated 9%)
#   adding: results/simple/with_mask/440.png (deflated 9%)
#   adding: results/simple/with_mask/902.png (deflated 9%)
#   adding: results/simple/with_mask/785.png (deflated 8%)
#   adding: results/simple/with_mask/458.png (deflated 8%)
#   adding: results/simple/with_mask/318.png (deflated 9%)
#   adding: results/simple/with_mask/86.png (deflated 9%)
#   adding: results/simple/with_mask/639.png (deflated 8%)
#   adding: results/simple/with_mask/495.png (deflated 8%)
#   adding: results/simple/with_mask/784.png (deflated 8%)
#   adding: results/simple/with_mask/176.png (deflated 8%)
#   adding: results/simple/with_mask/981.png (deflated 8%)
#   adding: results/simple/with_mask/359.png (deflated 9%)
#   adding: results/simple/with_mask/110.png (deflated 9%)
#   adding: results/simple/with_mask/546.png (deflated 9%)
#   adding: results/simple/with_mask/992.png (deflated 8%)
#   adding: results/simple/with_mask/704.png (deflated 8%)
#   adding: results/simple/with_mask/44.png (deflated 8%)
#   adding: results/simple/with_mask/959.png (deflated 9%)
#   adding: results/simple/with_mask/763.png (deflated 8%)
#   adding: results/simple/with_mask/840.png (deflated 9%)
#   adding: results/simple/with_mask/834.png (deflated 8%)
#   adding: results/simple/with_mask/776.png (deflated 8%)
#   adding: results/simple/with_mask/914.png (deflated 8%)
#   adding: results/simple/with_mask/41.png (deflated 9%)
#   adding: results/simple/with_mask/416.png (deflated 9%)
#   adding: results/simple/with_mask/800.png (deflated 8%)
#   adding: results/simple/with_mask/196.png (deflated 9%)
#   adding: results/simple/with_mask/691.png (deflated 9%)
#   adding: results/simple/with_mask/614.png (deflated 9%)
#   adding: results/simple/with_mask/267.png (deflated 8%)
#   adding: results/simple/with_mask/208.png (deflated 8%)
#   adding: results/simple/with_mask/392.png (deflated 9%)
#   adding: results/simple/with_mask/116.png (deflated 9%)
#   adding: results/simple/with_mask/68.png (deflated 9%)
#   adding: results/simple/with_mask/962.png (deflated 9%)
#   adding: results/simple/with_mask/731.png (deflated 8%)
#   adding: results/simple/with_mask/875.png (deflated 8%)
#   adding: results/simple/with_mask/438.png (deflated 8%)
#   adding: results/simple/with_mask/593.png (deflated 8%)
#   adding: results/simple/with_mask/24.png (deflated 8%)
#   adding: results/simple/with_mask/809.png (deflated 8%)
#   adding: results/simple/with_mask/395.png (deflated 8%)
#   adding: results/simple/with_mask/112.png (deflated 8%)
#   adding: results/simple/with_mask/38.png (deflated 8%)
#   adding: results/simple/with_mask/669.png (deflated 8%)
#   adding: results/simple/with_mask/864.png (deflated 7%)
#   adding: results/simple/with_mask/328.png (deflated 8%)
#   adding: results/simple/with_mask/367.png (deflated 8%)
#   adding: results/simple/with_mask/991.png (deflated 8%)
#   adding: results/simple/with_mask/958.png (deflated 8%)
#   adding: results/simple/with_mask/557.png (deflated 8%)
#   adding: results/simple/with_mask/335.png (deflated 8%)
#   adding: results/simple/with_mask/314.png (deflated 9%)
#   adding: results/simple/with_mask/797.png (deflated 9%)
#   adding: results/simple/with_mask/718.png (deflated 9%)
#   adding: results/simple/with_mask/657.png (deflated 8%)
#   adding: results/simple/with_mask/631.png (deflated 8%)
#   adding: results/simple/with_mask/524.png (deflated 9%)
#   adding: results/simple/with_mask/238.png (deflated 8%)
#   adding: results/simple/with_mask/562.png (deflated 8%)
#   adding: results/simple/with_mask/202.png (deflated 9%)
#   adding: results/simple/with_mask/406.png (deflated 8%)
#   adding: results/simple/with_mask/932.png (deflated 8%)
#   adding: results/simple/with_mask/996.png (deflated 9%)
#   adding: results/simple/with_mask/154.png (deflated 8%)
#   adding: results/simple/with_mask/787.png (deflated 9%)
#   adding: results/simple/with_mask/186.png (deflated 8%)
#   adding: results/simple/with_mask/259.png (deflated 9%)
#   adding: results/simple/with_mask/672.png (deflated 9%)
#   adding: results/simple/with_mask/671.png (deflated 9%)
#   adding: results/simple/with_mask/194.png (deflated 8%)
#   adding: results/simple/with_mask/896.png (deflated 9%)
#   adding: results/simple/with_mask/13.png (deflated 8%)
#   adding: results/simple/with_mask/76.png (deflated 8%)
#   adding: results/simple/with_mask/743.png (deflated 9%)
#   adding: results/simple/with_mask/811.png (deflated 9%)
#   adding: results/simple/with_mask/920.png (deflated 9%)
#   adding: results/simple/with_mask/443.png (deflated 9%)
#   adding: results/simple/with_mask/92.png (deflated 8%)
#   adding: results/simple/with_mask/402.png (deflated 8%)
#   adding: results/simple/with_mask/979.png (deflated 8%)
#   adding: results/simple/with_mask/442.png (deflated 8%)
#   adding: results/simple/with_mask/269.png (deflated 9%)
#   adding: results/simple/with_mask/304.png (deflated 9%)
#   adding: results/simple/with_mask/933.png (deflated 9%)
#   adding: results/simple/with_mask/432.png (deflated 9%)
#   adding: results/simple/with_mask/753.png (deflated 8%)
#   adding: results/simple/with_mask/450.png (deflated 8%)
#   adding: results/simple/with_mask/633.png (deflated 9%)
#   adding: results/simple/with_mask/386.png (deflated 8%)
#   adding: results/simple/with_mask/727.png (deflated 8%)
#   adding: results/simple/with_mask/104.png (deflated 9%)
#   adding: results/simple/with_mask/626.png (deflated 8%)
#   adding: results/simple/with_mask/516.png (deflated 8%)
#   adding: results/simple/with_mask/198.png (deflated 9%)
#   adding: results/simple/with_mask/55.png (deflated 9%)
#   adding: results/simple/with_mask/830.png (deflated 9%)
#   adding: results/simple/with_mask/5.png (deflated 9%)
#   adding: results/simple/with_mask/596.png (deflated 9%)
#   adding: results/simple/with_mask/865.png (deflated 8%)
#   adding: results/simple/with_mask/821.png (deflated 9%)
#   adding: results/simple/with_mask/324.png (deflated 8%)
#   adding: results/simple/with_mask/545.png (deflated 8%)
#   adding: results/simple/with_mask/241.png (deflated 8%)
#   adding: results/simple/with_mask/146.png (deflated 8%)
#   adding: results/simple/with_mask/998.png (deflated 9%)
#   adding: results/simple/with_mask/461.png (deflated 9%)
#   adding: results/simple/with_mask/375.png (deflated 9%)
#   adding: results/simple/with_mask/419.png (deflated 8%)
#   adding: results/simple/with_mask/332.png (deflated 8%)
#   adding: results/simple/with_mask/735.png (deflated 9%)
#   adding: results/simple/with_mask/752.png (deflated 9%)
#   adding: results/simple/with_mask/725.png (deflated 9%)
#   adding: results/simple/with_mask/427.png (deflated 8%)
#   adding: results/simple/with_mask/952.png (deflated 8%)
#   adding: results/simple/with_mask/316.png (deflated 9%)
#   adding: results/simple/with_mask/228.png (deflated 8%)
#   adding: results/simple/with_mask/147.png (deflated 8%)
#   adding: results/simple/with_mask/34.png (deflated 8%)
#   adding: results/simple/with_mask/575.png (deflated 9%)
#   adding: results/simple/with_mask/683.png (deflated 8%)
#   adding: results/simple/with_mask/988.png (deflated 8%)
#   adding: results/simple/with_mask/570.png (deflated 8%)
#   adding: results/simple/with_mask/453.png (deflated 8%)
#   adding: results/simple/with_mask/284.png (deflated 9%)
#   adding: results/simple/with_mask/32.png (deflated 9%)
#   adding: results/simple/with_mask/948.png (deflated 9%)
#   adding: results/simple/with_mask/431.png (deflated 9%)
#   adding: results/simple/with_mask/384.png (deflated 9%)
#   adding: results/simple/with_mask/621.png (deflated 9%)
#   adding: results/simple/with_mask/283.png (deflated 9%)
#   adding: results/simple/with_mask/580.png (deflated 9%)
#   adding: results/simple/with_mask/807.png (deflated 8%)
#   adding: results/simple/with_mask/153.png (deflated 9%)
#   adding: results/simple/with_mask/369.png (deflated 9%)
#   adding: results/simple/with_mask/460.png (deflated 9%)
#   adding: results/simple/with_mask/39.png (deflated 8%)
#   adding: results/simple/with_mask/72.png (deflated 8%)
#   adding: results/simple/with_mask/511.png (deflated 8%)
#   adding: results/simple/with_mask/690.png (deflated 8%)
#   adding: results/simple/with_mask/899.png (deflated 9%)
#   adding: results/simple/with_mask/543.png (deflated 8%)
#   adding: results/simple/with_mask/812.png (deflated 9%)
#   adding: results/simple/with_mask/410.png (deflated 9%)
#   adding: results/simple/with_mask/740.png (deflated 9%)
#   adding: results/simple/with_mask/98.png (deflated 10%)
#   adding: results/simple/with_mask/835.png (deflated 9%)
#   adding: results/simple/with_mask/82.png (deflated 8%)
#   adding: results/simple/with_mask/624.png (deflated 8%)
#   adding: results/simple/with_mask/581.png (deflated 9%)
#   adding: results/simple/with_mask/980.png (deflated 9%)
#   adding: results/simple/with_mask/423.png (deflated 9%)
#   adding: results/simple/with_mask/229.png (deflated 8%)
#   adding: results/simple/with_mask/444.png (deflated 8%)
#   adding: results/simple/with_mask/925.png (deflated 8%)
#   adding: results/simple/with_mask/256.png (deflated 9%)
#   adding: results/simple/with_mask/345.png (deflated 8%)
#   adding: results/simple/with_mask/125.png (deflated 8%)
#   adding: results/simple/with_mask/282.png (deflated 8%)
#   adding: results/simple/with_mask/777.png (deflated 9%)
#   adding: results/simple/with_mask/35.png (deflated 9%)
#   adding: results/simple/with_mask/831.png (deflated 9%)
#   adding: results/simple/with_mask/220.png (deflated 8%)
#   adding: results/simple/with_mask/898.png (deflated 8%)
#   adding: results/simple/with_mask/975.png (deflated 10%)
#   adding: results/simple/with_mask/224.png (deflated 8%)
#   adding: results/simple/with_mask/555.png (deflated 8%)
#   adding: results/simple/with_mask/592.png (deflated 8%)
#   adding: results/simple/with_mask/274.png (deflated 8%)
#   adding: results/simple/with_mask/143.png (deflated 8%)
#   adding: results/simple/with_mask/779.png (deflated 8%)
#   adding: results/simple/with_mask/436.png (deflated 9%)
#   adding: results/simple/with_mask/300.png (deflated 9%)
#   adding: results/simple/with_mask/178.png (deflated 8%)
#   adding: results/simple/with_mask/496.png (deflated 8%)
#   adding: results/simple/with_mask/459.png (deflated 8%)
#   adding: results/simple/with_mask/126.png (deflated 8%)
#   adding: results/simple/with_mask/188.png (deflated 9%)
#   adding: results/simple/with_mask/246.png (deflated 9%)
#   adding: results/simple/with_mask/290.png (deflated 8%)
#   adding: results/simple/with_mask/197.png (deflated 9%)
#   adding: results/simple/with_mask/123.png (deflated 8%)
#   adding: results/simple/with_mask/552.png (deflated 9%)
#   adding: results/simple/with_mask/484.png (deflated 9%)
#   adding: results/simple/with_mask/602.png (deflated 8%)
#   adding: results/simple/with_mask/947.png (deflated 9%)
#   adding: results/simple/with_mask/828.png (deflated 8%)
#   adding: results/simple/with_mask/170.png (deflated 8%)
#   adding: results/simple/with_mask/235.png (deflated 9%)
#   adding: results/simple/with_mask/916.png (deflated 9%)
#   adding: results/simple/with_mask/608.png (deflated 8%)
#   adding: results/simple/with_mask/433.png (deflated 9%)
#   adding: results/simple/with_mask/321.png (deflated 9%)
#   adding: results/simple/with_mask/765.png (deflated 9%)
#   adding: results/simple/with_mask/40.png (deflated 8%)
#   adding: results/simple/with_mask/364.png (deflated 9%)
#   adding: results/simple/with_mask/232.png (deflated 9%)
#   adding: results/simple/with_mask/107.png (deflated 8%)
#   adding: results/simple/with_mask/684.png (deflated 9%)
#   adding: results/simple/with_mask/103.png (deflated 8%)
#   adding: results/simple/with_mask/209.png (deflated 8%)
#   adding: results/simple/with_mask/400.png (deflated 9%)
#   adding: results/simple/with_mask/148.png (deflated 8%)
#   adding: results/simple/with_mask/868.png (deflated 8%)
#   adding: results/simple/with_mask/680.png (deflated 9%)
#   adding: results/simple/with_mask/354.png (deflated 8%)
#   adding: results/simple/with_mask/558.png (deflated 9%)
#   adding: results/simple/with_mask/535.png (deflated 8%)
#   adding: results/simple/with_mask/425.png (deflated 8%)
#   adding: results/simple/with_mask/294.png (deflated 8%)
#   adding: results/simple/with_mask/218.png (deflated 8%)
#   adding: results/simple/with_mask/553.png (deflated 9%)
#   adding: results/simple/with_mask/297.png (deflated 9%)
#   adding: results/simple/with_mask/579.png (deflated 8%)
#   adding: results/simple/with_mask/659.png (deflated 9%)
#   adding: results/simple/with_mask/911.png (deflated 9%)
#   adding: results/simple/with_mask/105.png (deflated 8%)
#   adding: results/simple/with_mask/348.png (deflated 8%)
#   adding: results/simple/with_mask/519.png (deflated 8%)
#   adding: results/simple/with_mask/877.png (deflated 8%)
#   adding: results/simple/with_mask/490.png (deflated 8%)
#   adding: results/simple/with_mask/394.png (deflated 8%)
#   adding: results/simple/with_mask/857.png (deflated 9%)
#   adding: results/simple/with_mask/550.png (deflated 8%)
#   adding: results/simple/with_mask/397.png (deflated 9%)
#   adding: results/simple/with_mask/732.png (deflated 9%)
#   adding: results/simple/with_mask/673.png (deflated 8%)
#   adding: results/simple/with_mask/793.png (deflated 8%)
#   adding: results/simple/with_mask/728.png (deflated 8%)
#   adding: results/simple/with_mask/966.png (deflated 8%)
#   adding: results/simple/with_mask/260.png (deflated 9%)
#   adding: results/simple/with_mask/860.png (deflated 9%)
#   adding: results/simple/with_mask/180.png (deflated 8%)
#   adding: results/simple/with_mask/715.png (deflated 9%)
#   adding: results/simple/with_mask/200.png (deflated 9%)
#   adding: results/simple/with_mask/852.png (deflated 9%)
#   adding: results/simple/with_mask/618.png (deflated 8%)
#   adding: results/simple/with_mask/373.png (deflated 8%)
#   adding: results/simple/with_mask/120.png (deflated 8%)
#   adding: results/simple/with_mask/662.png (deflated 9%)
#   adding: results/simple/with_mask/296.png (deflated 8%)
#   adding: results/simple/with_mask/663.png (deflated 8%)
#   adding: results/simple/with_mask/219.png (deflated 8%)
#   adding: results/simple/with_mask/124.png (deflated 8%)
#   adding: results/simple/with_mask/62.png (deflated 8%)
#   adding: results/simple/with_mask/841.png (deflated 9%)
#   adding: results/simple/with_mask/641.png (deflated 9%)
#   adding: results/simple/with_mask/494.png (deflated 8%)
#   adding: results/simple/with_mask/491.png (deflated 9%)
#   adding: results/simple/with_mask/768.png (deflated 9%)
#   adding: results/simple/with_mask/993.png (deflated 8%)
#   adding: results/simple/with_mask/507.png (deflated 9%)
#   adding: results/simple/with_mask/600.png (deflated 8%)
#   adding: results/simple/with_mask/512.png (deflated 9%)
#   adding: results/simple/with_mask/140.png (deflated 8%)
#   adding: results/simple/with_mask/372.png (deflated 8%)
#   adding: results/simple/with_mask/89.png (deflated 9%)
#   adding: results/simple/with_mask/70.png (deflated 8%)
#   adding: results/simple/with_mask/612.png (deflated 9%)
#   adding: results/simple/with_mask/339.png (deflated 9%)
#   adding: results/simple/with_mask/289.png (deflated 8%)
#   adding: results/simple/with_mask/390.png (deflated 8%)
#   adding: results/simple/with_mask/129.png (deflated 8%)
#   adding: results/simple/with_mask/338.png (deflated 8%)
#   adding: results/simple/with_mask/87.png (deflated 9%)
#   adding: results/simple/with_mask/644.png (deflated 9%)
#   adding: results/simple/with_mask/343.png (deflated 9%)
#   adding: results/simple/with_mask/851.png (deflated 8%)
#   adding: results/simple/with_mask/668.png (deflated 9%)
#   adding: results/simple/with_mask/298.png (deflated 8%)
#   adding: results/simple/with_mask/686.png (deflated 8%)
#   adding: results/simple/with_mask/906.png (deflated 9%)
#   adding: results/simple/with_mask/826.png (deflated 9%)
#   adding: results/simple/with_mask/878.png (deflated 9%)
#   adding: results/simple/with_mask/568.png (deflated 8%)
#   adding: results/simple/with_mask/871.png (deflated 8%)
#   adding: results/simple/with_mask/817.png (deflated 9%)
#   adding: results/simple/with_mask/377.png (deflated 9%)
#   adding: results/simple/with_mask/883.png (deflated 9%)
#   adding: results/simple/with_mask/517.png (deflated 8%)
#   adding: results/simple/with_mask/919.png (deflated 9%)
#   adding: results/simple/with_mask/182.png (deflated 9%)
#   adding: results/simple/with_mask/842.png (deflated 8%)
#   adding: results/simple/with_mask/587.png (deflated 9%)
#   adding: results/simple/with_mask/396.png (deflated 9%)
#   adding: results/simple/with_mask/951.png (deflated 9%)
#   adding: results/simple/with_mask/356.png (deflated 9%)
#   adding: results/simple/with_mask/970.png (deflated 9%)
#   adding: results/simple/with_mask/750.png (deflated 8%)
#   adding: results/simple/with_mask/331.png (deflated 9%)
#   adding: results/simple/with_mask/346.png (deflated 9%)
#   adding: results/simple/with_mask/168.png (deflated 8%)
#   adding: results/simple/with_mask/620.png (deflated 8%)
#   adding: results/simple/with_mask/733.png (deflated 8%)
#   adding: results/simple/with_mask/751.png (deflated 9%)
#   adding: results/simple/with_mask/193.png (deflated 8%)
#   adding: results/simple/with_mask/722.png (deflated 9%)
#   adding: results/simple/with_mask/601.png (deflated 8%)
#   adding: results/simple/with_mask/656.png (deflated 8%)
#   adding: results/simple/with_mask/604.png (deflated 8%)
#   adding: results/simple/with_mask/766.png (deflated 8%)
#   adding: results/simple/with_mask/163.png (deflated 8%)
#   adding: results/simple/with_mask/832.png (deflated 9%)
#   adding: results/simple/with_mask/214.png (deflated 8%)
#   adding: results/simple/with_mask/292.png (deflated 8%)
#   adding: results/simple/with_mask/782.png (deflated 8%)
#   adding: results/simple/with_mask/984.png (deflated 9%)
#   adding: results/simple/with_mask/819.png (deflated 8%)
#   adding: results/simple/with_mask/520.png (deflated 8%)
#   adding: results/simple/with_mask/810.png (deflated 9%)
#   adding: results/simple/with_mask/843.png (deflated 8%)
#   adding: results/simple/with_mask/532.png (deflated 9%)
#   adding: results/simple/with_mask/625.png (deflated 8%)
#   adding: results/simple/with_mask/114.png (deflated 8%)
#   adding: results/simple/with_mask/559.png (deflated 9%)
#   adding: results/simple/with_mask/679.png (deflated 9%)
#   adding: results/simple/with_mask/106.png (deflated 9%)
#   adding: results/simple/with_mask/569.png (deflated 8%)
#   adding: results/simple/with_mask/894.png (deflated 9%)
#   adding: results/simple/with_mask/564.png (deflated 8%)
#   adding: results/simple/with_mask/971.png (deflated 8%)
#   adding: results/simple/with_mask/904.png (deflated 8%)
#   adding: results/simple/with_mask/201.png (deflated 8%)
#   adding: results/simple/with_mask/281.png (deflated 9%)
#   adding: results/simple/with_mask/234.png (deflated 8%)
#   adding: results/simple/with_mask/387.png (deflated 9%)
#   adding: results/simple/with_mask/542.png (deflated 8%)
#   adding: results/simple/with_mask/293.png (deflated 8%)
#   adding: results/simple/with_mask/91.png (deflated 8%)
#   adding: results/simple/with_mask/658.png (deflated 9%)
#   adding: results/simple/with_mask/934.png (deflated 9%)
#   adding: results/simple/with_mask/336.png (deflated 9%)
#   adding: results/simple/with_mask/291.png (deflated 8%)
#   adding: results/simple/with_mask/627.png (deflated 9%)
#   adding: results/simple/with_mask/227.png (deflated 8%)
#   adding: results/simple/with_mask/589.png (deflated 8%)
#   adding: results/simple/with_mask/413.png (deflated 9%)
#   adding: results/simple/with_mask/191.png (deflated 8%)
#   adding: results/simple/with_mask/603.png (deflated 9%)
#   adding: results/simple/with_mask/326.png (deflated 8%)
#   adding: results/simple/with_mask/551.png (deflated 8%)
#   adding: results/simple/with_mask/469.png (deflated 8%)
#   adding: results/simple/with_mask/199.png (deflated 9%)
#   adding: results/simple/with_mask/94.png (deflated 8%)
#   adding: results/simple/with_mask/65.png (deflated 9%)
#   adding: results/simple/with_mask/439.png (deflated 9%)
#   adding: results/simple/with_mask/27.png (deflated 9%)
#   adding: results/simple/with_mask/236.png (deflated 9%)
#   adding: results/simple/with_mask/8.png (deflated 8%)
#   adding: results/simple/with_mask/139.png (deflated 8%)
#   adding: results/simple/with_mask/84.png (deflated 8%)
#   adding: results/simple/with_mask/525.png (deflated 9%)
#   adding: results/simple/with_mask/421.png (deflated 8%)
#   adding: results/simple/with_mask/454.png (deflated 8%)
#   adding: results/simple/with_mask/133.png (deflated 9%)
#   adding: results/simple/with_mask/156.png (deflated 8%)
#   adding: results/simple/with_mask/849.png (deflated 9%)
#   adding: results/simple/with_mask/166.png (deflated 9%)
#   adding: results/simple/with_mask/628.png (deflated 8%)
#   adding: results/simple/with_mask/472.png (deflated 9%)
#   adding: results/simple/with_mask/451.png (deflated 9%)
#   adding: results/simple/with_mask/119.png (deflated 8%)
#   adding: results/simple/with_mask/108.png (deflated 9%)
#   adding: results/simple/with_mask/873.png (deflated 9%)
#   adding: results/simple/with_mask/488.png (deflated 8%)
#   adding: results/simple/with_mask/588.png (deflated 9%)
#   adding: results/simple/with_mask/213.png (deflated 8%)
#   adding: results/simple/with_mask/497.png (deflated 8%)
#   adding: results/simple/with_mask/137.png (deflated 8%)
#   adding: results/simple/with_mask/573.png (deflated 9%)
#   adding: results/simple/with_mask/824.png (deflated 8%)
#   adding: results/simple/with_mask/565.png (deflated 8%)
#   adding: results/simple/with_mask/480.png (deflated 8%)
#   adding: results/simple/with_mask/349.png (deflated 8%)
#   adding: results/simple/with_mask/457.png (deflated 8%)
#   adding: results/simple/with_mask/719.png (deflated 8%)
#   adding: results/simple/with_mask/428.png (deflated 9%)
#   adding: results/simple/with_mask/645.png (deflated 8%)
#   adding: results/simple/with_mask/15.png (deflated 9%)
#   adding: results/simple/with_mask/944.png (deflated 8%)
#   adding: results/simple/with_mask/827.png (deflated 9%)
#   adding: results/simple/with_mask/258.png (deflated 9%)
#   adding: results/simple/with_mask/838.png (deflated 9%)
#   adding: results/simple/with_mask/77.png (deflated 9%)
#   adding: results/simple/with_mask/833.png (deflated 9%)
#   adding: results/simple/with_mask/350.png (deflated 8%)
#   adding: results/simple/with_mask/931.png (deflated 9%)
#   adding: results/simple/with_mask/803.png (deflated 8%)
#   adding: results/simple/with_mask/648.png (deflated 8%)
#   adding: results/simple/with_mask/11.png (deflated 9%)
#   adding: results/simple/with_mask/675.png (deflated 9%)
#   adding: results/simple/with_mask/712.png (deflated 8%)
#   adding: results/simple/with_mask/858.png (deflated 8%)
#   adding: results/simple/with_mask/736.png (deflated 9%)
#   adding: results/simple/with_mask/972.png (deflated 9%)
#   adding: results/simple/with_mask/945.png (deflated 8%)
#   adding: results/simple/with_mask/815.png (deflated 9%)
#   adding: results/simple/with_mask/598.png (deflated 9%)
#   adding: results/simple/with_mask/270.png (deflated 8%)
#   adding: results/simple/with_mask/248.png (deflated 9%)
#   adding: results/simple/with_mask/301.png (deflated 8%)
#   adding: results/simple/with_mask/311.png (deflated 8%)
#   adding: results/simple/with_mask/330.png (deflated 8%)
#   adding: results/simple/with_mask/737.png (deflated 9%)
#   adding: results/simple/with_mask/449.png (deflated 9%)
#   adding: results/simple/with_mask/366.png (deflated 9%)
#   adding: results/simple/with_mask/870.png (deflated 9%)
#   adding: results/simple/with_mask/760.png (deflated 9%)
#   adding: results/simple/with_mask/462.png (deflated 8%)
#   adding: results/simple/with_mask/58.png (deflated 9%)
#   adding: results/simple/with_mask/273.png (deflated 9%)
#   adding: results/simple/with_mask/567.png (deflated 9%)
#   adding: results/simple/with_mask/181.png (deflated 9%)
#   adding: results/simple/with_mask/26.png (deflated 9%)
#   adding: results/simple/with_mask/430.png (deflated 8%)
#   adding: results/simple/with_mask/995.png (deflated 9%)
#   adding: results/simple/with_mask/940.png (deflated 8%)
#   adding: results/simple/with_mask/762.png (deflated 9%)
#   adding: results/simple/with_mask/414.png (deflated 8%)
#   adding: results/simple/with_mask/403.png (deflated 8%)
#   adding: results/simple/with_mask/299.png (deflated 8%)
#   adding: results/simple/with_mask/693.png (deflated 9%)
#   adding: results/simple/with_mask/205.png (deflated 9%)
#   adding: results/simple/with_mask/361.png (deflated 9%)
#   adding: results/simple/with_mask/255.png (deflated 9%)
#   adding: results/simple/with_mask/504.png (deflated 9%)
#   adding: results/simple/with_mask/59.png (deflated 8%)
#   adding: results/simple/with_mask/252.png (deflated 8%)
#   adding: results/simple/with_mask/263.png (deflated 8%)
#   adding: results/simple/with_mask/498.png (deflated 8%)
#   adding: results/simple/with_mask/957.png (deflated 8%)
#   adding: results/simple/with_mask/989.png (deflated 8%)
#   adding: results/simple/with_mask/452.png (deflated 8%)
#   adding: results/simple/with_mask/211.png (deflated 9%)
#   adding: results/simple/with_mask/155.png (deflated 8%)
#   adding: results/simple/with_mask/985.png (deflated 8%)
#   adding: results/simple/with_mask/169.png (deflated 8%)
#   adding: results/simple/with_mask/424.png (deflated 9%)
#   adding: results/simple/with_mask/862.png (deflated 9%)
#   adding: results/simple/with_mask/83.png (deflated 8%)
#   adding: results/simple/with_mask/795.png (deflated 9%)
#   adding: results/simple/with_mask/418.png (deflated 9%)
#   adding: results/simple/with_mask/909.png (deflated 9%)
#   adding: results/simple/with_mask/78.png (deflated 9%)
#   adding: results/simple/with_mask/929.png (deflated 9%)
#   adding: results/simple/with_mask/505.png (deflated 8%)
#   adding: results/simple/with_mask/303.png (deflated 8%)
#   adding: results/simple/with_mask/448.png (deflated 8%)
#   adding: results/simple/with_mask/97.png (deflated 8%)
#   adding: results/simple/with_mask/45.png (deflated 9%)
#   adding: results/simple/with_mask/655.png (deflated 9%)
#   adding: results/simple/with_mask/280.png (deflated 8%)
#   adding: results/simple/with_mask/509.png (deflated 9%)
#   adding: results/simple/with_mask/93.png (deflated 9%)
#   adding: results/simple/with_mask/489.png (deflated 8%)
#   adding: results/simple/with_mask/590.png (deflated 8%)
#   adding: results/simple/with_mask/705.png (deflated 9%)
#   adding: results/simple/with_mask/216.png (deflated 8%)
#   adding: results/simple/with_mask/897.png (deflated 8%)
#   adding: results/simple/with_mask/742.png (deflated 9%)
#   adding: results/simple/with_mask/584.png (deflated 8%)
#   adding: results/simple/with_mask/150.png (deflated 9%)
#   adding: results/simple/with_mask/7.png (deflated 8%)
#   adding: results/simple/with_mask/711.png (deflated 8%)
#   adding: results/simple/with_mask/935.png (deflated 9%)
#   adding: results/simple/with_mask/818.png (deflated 9%)
#   adding: results/simple/with_mask/36.png (deflated 8%)
#   adding: results/simple/with_mask/134.png (deflated 9%)
#   adding: results/simple/with_mask/910.png (deflated 8%)
#   adding: results/simple/with_mask/572.png (deflated 9%)
#   adding: results/simple/with_mask/726.png (deflated 8%)
#   adding: results/simple/with_mask/923.png (deflated 8%)
#   adding: results/simple/with_mask/131.png (deflated 8%)
#   adding: results/simple/with_mask/901.png (deflated 8%)
#   adding: results/simple/with_mask/37.png (deflated 9%)
#   adding: results/simple/with_mask/848.png (deflated 9%)
#   adding: results/simple/with_mask/257.png (deflated 9%)
#   adding: results/simple/with_mask/363.png (deflated 9%)
#   adding: results/simple/with_mask/385.png (deflated 9%)
#   adding: results/simple/with_mask/187.png (deflated 9%)
#   adding: results/simple/with_mask/949.png (deflated 9%)
#   adding: results/simple/with_mask/276.png (deflated 8%)
#   adding: results/simple/with_mask/399.png (deflated 9%)
#   adding: results/simple/with_mask/650.png (deflated 8%)
#   adding: results/simple/with_mask/179.png (deflated 9%)
#   adding: results/simple/with_mask/582.png (deflated 8%)
#   adding: results/simple/with_mask/151.png (deflated 8%)
#   adding: results/simple/with_mask/974.png (deflated 8%)
#   adding: results/simple/with_mask/967.png (deflated 9%)
#   adding: results/simple/with_mask/635.png (deflated 8%)
#   adding: results/simple/with_mask/295.png (deflated 8%)
#   adding: results/simple/with_mask/739.png (deflated 8%)
#   adding: results/simple/with_mask/744.png (deflated 9%)
#   adding: results/simple/with_mask/523.png (deflated 9%)
#   adding: results/simple/with_mask/808.png (deflated 8%)
#   adding: results/simple/with_mask/244.png (deflated 9%)
#   adding: results/simple/with_mask/30.png (deflated 8%)
#   adding: results/simple/with_mask/946.png (deflated 9%)
#   adding: results/simple/with_mask/730.png (deflated 8%)
#   adding: results/simple/with_mask/96.png (deflated 9%)
#   adding: results/simple/with_mask/853.png (deflated 8%)
#   adding: results/simple/with_mask/144.png (deflated 8%)
#   adding: results/simple/with_mask/771.png (deflated 8%)
#   adding: results/simple/with_mask/764.png (deflated 8%)
#   adding: results/simple/with_mask/315.png (deflated 9%)
#   adding: results/simple/with_mask/389.png (deflated 8%)
#   adding: results/simple/with_mask/20.png (deflated 8%)
#   adding: results/simple/with_mask/67.png (deflated 8%)
#   adding: results/simple/with_mask/529.png (deflated 8%)
#   adding: results/simple/with_mask/487.png (deflated 8%)
#   adding: results/simple/with_mask/876.png (deflated 9%)
#   adding: results/simple/with_mask/262.png (deflated 8%)
#   adding: results/simple/with_mask/629.png (deflated 9%)
#   adding: results/simple/with_mask/513.png (deflated 9%)
#   adding: results/simple/with_mask/823.png (deflated 9%)
#   adding: results/simple/with_mask/999.png (deflated 9%)
#   adding: results/simple/with_mask/855.png (deflated 9%)
#   adding: results/simple/with_mask/456.png (deflated 8%)
#   adding: results/simple/with_mask/503.png (deflated 9%)
#   adding: results/simple/with_mask/305.png (deflated 8%)
#   adding: results/simple/with_mask/327.png (deflated 9%)
#   adding: results/simple/with_mask/665.png (deflated 9%)
#   adding: results/simple/with_mask/466.png (deflated 9%)
#   adding: results/simple/with_mask/789.png (deflated 8%)
#   adding: results/simple/with_mask/889.png (deflated 8%)
#   adding: results/simple/with_mask/175.png (deflated 8%)
#   adding: results/simple/with_mask/619.png (deflated 8%)
#   adding: results/simple/with_mask/632.png (deflated 8%)
#   adding: results/simple/with_mask/203.png (deflated 9%)
#   adding: results/simple/with_mask/383.png (deflated 8%)
#   adding: results/simple/with_mask/794.png (deflated 8%)
#   adding: results/simple/with_mask/859.png (deflated 8%)
#   adding: results/simple/with_mask/890.png (deflated 8%)
#   adding: results/simple/with_mask/307.png (deflated 8%)
#   adding: results/simple/with_mask/748.png (deflated 8%)
#   adding: results/simple/with_mask/717.png (deflated 9%)
#   adding: results/simple/with_mask/506.png (deflated 9%)
#   adding: results/simple/with_mask/930.png (deflated 9%)
#   adding: results/simple/with_mask/275.png (deflated 8%)
#   adding: results/simple/with_mask/912.png (deflated 9%)
#   adding: results/simple/with_mask/829.png (deflated 8%)
#   adding: results/simple/with_mask/696.png (deflated 8%)
#   adding: results/simple/with_mask/56.png (deflated 9%)
#   adding: results/simple/with_mask/319.png (deflated 9%)
#   adding: results/simple/with_mask/222.png (deflated 9%)
#   adding: results/simple/with_mask/918.png (deflated 9%)
#   adding: results/simple/with_mask/344.png (deflated 8%)
#   adding: results/simple/with_mask/804.png (deflated 8%)
#   adding: results/simple/with_mask/960.png (deflated 9%)
#   adding: results/simple/with_mask/117.png (deflated 9%)
#   adding: results/simple/with_mask/900.png (deflated 9%)
#   adding: results/simple/with_mask/560.png (deflated 8%)
#   adding: results/simple/with_mask/714.png (deflated 8%)
#   adding: results/simple/with_mask/963.png (deflated 9%)
#   adding: results/simple/with_mask/352.png (deflated 8%)
#   adding: results/simple/with_mask/917.png (deflated 8%)
#   adding: results/simple/with_mask/95.png (deflated 9%)
#   adding: results/simple/with_mask/145.png (deflated 8%)
#   adding: results/simple/with_mask/585.png (deflated 9%)
#   adding: results/simple/with_mask/12.png (deflated 8%)
# ...
#   adding: results/simple/without_mask/280.png (deflated 8%)
#   adding: results/simple/without_mask/509.png (deflated 9%)
#   adding: results/simple/without_mask/93.png (deflated 8%)
#   adding: results/simple/without_mask/489.png (deflated 9%)
#   adding: results/simple/without_mask/590.png (deflated 9%)
#   adding: results/simple/without_mask/705.png (deflated 8%)
#   adding: results/simple/without_mask/216.png (deflated 8%)
#   adding: results/simple/without_mask/897.png (deflated 8%)
#   adding: results/simple/without_mask/742.png (deflated 8%)
#   adding: results/simple/without_mask/584.png (deflated 8%)
#   adding: results/simple/without_mask/150.png (deflated 9%)
#   adding: results/simple/without_mask/7.png (deflated 8%)
#   adding: results/simple/without_mask/711.png (deflated 9%)
#   adding: results/simple/without_mask/935.png (deflated 8%)
#   adding: results/simple/without_mask/818.png (deflated 8%)
#   adding: results/simple/without_mask/36.png (deflated 8%)
#   adding: results/simple/without_mask/134.png (deflated 8%)
#   adding: results/simple/without_mask/910.png (deflated 9%)
#   adding: results/simple/without_mask/572.png (deflated 9%)
#   adding: results/simple/without_mask/726.png (deflated 8%)
#   adding: results/simple/without_mask/923.png (deflated 8%)
#   adding: results/simple/without_mask/131.png (deflated 8%)
#   adding: results/simple/without_mask/901.png (deflated 8%)
#   adding: results/simple/without_mask/37.png (deflated 8%)
#   adding: results/simple/without_mask/848.png (deflated 8%)
#   adding: results/simple/without_mask/257.png (deflated 8%)
#   adding: results/simple/without_mask/363.png (deflated 8%)
#   adding: results/simple/without_mask/385.png (deflated 8%)
#   adding: results/simple/without_mask/187.png (deflated 9%)
#   adding: results/simple/without_mask/949.png (deflated 8%)
#   adding: results/simple/without_mask/276.png (deflated 8%)
#   adding: results/simple/without_mask/399.png (deflated 9%)
#   adding: results/simple/without_mask/650.png (deflated 8%)
#   adding: results/simple/without_mask/179.png (deflated 8%)
#   adding: results/simple/without_mask/582.png (deflated 8%)
#   adding: results/simple/without_mask/151.png (deflated 8%)
#   adding: results/simple/without_mask/974.png (deflated 8%)
#   adding: results/simple/without_mask/967.png (deflated 8%)
#   adding: results/simple/without_mask/635.png (deflated 8%)
#   adding: results/simple/without_mask/295.png (deflated 8%)
#   adding: results/simple/without_mask/739.png (deflated 8%)
#   adding: results/simple/without_mask/744.png (deflated 9%)
#   adding: results/simple/without_mask/523.png (deflated 9%)
#   adding: results/simple/without_mask/808.png (deflated 9%)
#   adding: results/simple/without_mask/244.png (deflated 8%)
#   adding: results/simple/without_mask/30.png (deflated 8%)
#   adding: results/simple/without_mask/946.png (deflated 9%)
#   adding: results/simple/without_mask/730.png (deflated 9%)
#   adding: results/simple/without_mask/96.png (deflated 8%)
#   adding: results/simple/without_mask/853.png (deflated 8%)
#   adding: results/simple/without_mask/144.png (deflated 9%)
#   adding: results/simple/without_mask/771.png (deflated 9%)
#   adding: results/simple/without_mask/764.png (deflated 8%)
#   adding: results/simple/without_mask/315.png (deflated 9%)
#   adding: results/simple/without_mask/389.png (deflated 8%)
#   adding: results/simple/without_mask/20.png (deflated 8%)
#   adding: results/simple/without_mask/67.png (deflated 8%)
#   adding: results/simple/without_mask/529.png (deflated 9%)
#   adding: results/simple/without_mask/487.png (deflated 8%)
#   adding: results/simple/without_mask/876.png (deflated 9%)
#   adding: results/simple/without_mask/262.png (deflated 8%)
#   adding: results/simple/without_mask/629.png (deflated 9%)
#   adding: results/simple/without_mask/513.png (deflated 9%)
#   adding: results/simple/without_mask/823.png (deflated 8%)
#   adding: results/simple/without_mask/999.png (deflated 8%)
#   adding: results/simple/without_mask/855.png (deflated 8%)
#   adding: results/simple/without_mask/456.png (deflated 8%)
#   adding: results/simple/without_mask/503.png (deflated 8%)
#   adding: results/simple/without_mask/305.png (deflated 8%)
#   adding: results/simple/without_mask/327.png (deflated 9%)
#   adding: results/simple/without_mask/665.png (deflated 9%)
#   adding: results/simple/without_mask/466.png (deflated 8%)
#   adding: results/simple/without_mask/789.png (deflated 8%)
#   adding: results/simple/without_mask/889.png (deflated 8%)
#   adding: results/simple/without_mask/175.png (deflated 8%)
#   adding: results/simple/without_mask/619.png (deflated 8%)
#   adding: results/simple/without_mask/632.png (deflated 9%)
#   adding: results/simple/without_mask/203.png (deflated 8%)
#   adding: results/simple/without_mask/383.png (deflated 8%)
#   adding: results/simple/without_mask/794.png (deflated 9%)
#   adding: results/simple/without_mask/859.png (deflated 8%)
#   adding: results/simple/without_mask/890.png (deflated 9%)
#   adding: results/simple/without_mask/307.png (deflated 8%)
#   adding: results/simple/without_mask/748.png (deflated 9%)
#   adding: results/simple/without_mask/717.png (deflated 9%)
#   adding: results/simple/without_mask/506.png (deflated 8%)
#   adding: results/simple/without_mask/930.png (deflated 8%)
#   adding: results/simple/without_mask/275.png (deflated 8%)
#   adding: results/simple/without_mask/912.png (deflated 8%)
#   adding: results/simple/without_mask/829.png (deflated 9%)
#   adding: results/simple/without_mask/696.png (deflated 8%)
#   adding: results/simple/without_mask/56.png (deflated 9%)
#   adding: results/simple/without_mask/319.png (deflated 8%)
#   adding: results/simple/without_mask/222.png (deflated 9%)
#   adding: results/simple/without_mask/918.png (deflated 8%)
#   adding: results/simple/without_mask/344.png (deflated 8%)
#   adding: results/simple/without_mask/804.png (deflated 8%)
#   adding: results/simple/without_mask/960.png (deflated 8%)
#   adding: results/simple/without_mask/117.png (deflated 9%)
#   adding: results/simple/without_mask/900.png (deflated 9%)
#   adding: results/simple/without_mask/560.png (deflated 9%)
#   adding: results/simple/without_mask/714.png (deflated 8%)
#   adding: results/simple/without_mask/963.png (deflated 8%)
#   adding: results/simple/without_mask/352.png (deflated 8%)
#   adding: results/simple/without_mask/917.png (deflated 9%)
#   adding: results/simple/without_mask/95.png (deflated 9%)
#   adding: results/simple/without_mask/145.png (deflated 8%)
#   adding: results/simple/without_mask/585.png (deflated 9%)
#   adding: results/simple/without_mask/12.png (deflated 8%)
#   adding: results/simple/without_mask/915.png (deflated 8%)
#   adding: results/simple/without_mask/630.png (deflated 9%)
#   adding: results/simple/without_mask/90.png (deflated 8%)
#   adding: results/simple/without_mask/846.png (deflated 8%)
#   adding: results/simple/without_mask/435.png (deflated 8%)
#   adding: results/simple/without_mask/927.png (deflated 9%)
#   adding: results/simple/without_mask/477.png (deflated 9%)
#   adding: results/simple/without_mask/805.png (deflated 9%)
#   adding: results/simple/without_mask/167.png (deflated 9%)
#   adding: results/simple/without_mask/734.png (deflated 9%)
#   adding: results/simple/without_mask/22.png (deflated 8%)
#   adding: results/simple/without_mask/549.png (deflated 9%)
#   adding: results/simple/without_mask/306.png (deflated 9%)
#   adding: results/simple/without_mask/510.png (deflated 8%)
#   adding: results/simple/without_mask/854.png (deflated 8%)
#   adding: results/simple/without_mask/320.png (deflated 9%)
#   adding: results/simple/without_mask/697.png (deflated 9%)
#   adding: results/simple/without_mask/786.png (deflated 9%)
#   adding: results/simple/without_mask/982.png (deflated 9%)
#   adding: results/simple/without_mask/822.png (deflated 8%)
#   adding: results/simple/without_mask/599.png (deflated 8%)
#   adding: results/simple/without_mask/237.png (deflated 9%)
#   adding: results/simple/without_mask/142.png (deflated 8%)
#   adding: results/simple/without_mask/790.png (deflated 9%)
#   adding: results/simple/without_mask/464.png (deflated 9%)
#   adding: results/simple/without_mask/879.png (deflated 8%)
#   adding: results/simple/without_mask/775.png (deflated 8%)
#   adding: results/simple/without_mask/118.png (deflated 8%)
#   adding: results/simple/without_mask/692.png (deflated 8%)
#   adding: results/simple/without_mask/702.png (deflated 9%)
#   adding: results/simple/without_mask/100.png (deflated 9%)
#   adding: results/simple/without_mask/561.png (deflated 9%)
#   adding: results/simple/without_mask/781.png (deflated 9%)
#   adding: results/simple/without_mask/66.png (deflated 8%)
#   adding: results/simple/without_mask/195.png (deflated 8%)
#   adding: results/simple/without_mask/173.png (deflated 9%)
#   adding: results/simple/without_mask/206.png (deflated 9%)
#   adding: results/simple/without_mask/676.png (deflated 9%)
#   adding: results/simple/without_mask/544.png (deflated 8%)
#   adding: results/simple/without_mask/577.png (deflated 8%)
#   adding: results/simple/without_mask/99.png (deflated 9%)
#   adding: results/simple/without_mask/113.png (deflated 8%)
#   adding: results/simple/without_mask/493.png (deflated 8%)
#   adding: results/simple/without_mask/939.png (deflated 8%)
#   adding: results/simple/without_mask/251.png (deflated 8%)
#   adding: results/simple/without_mask/253.png (deflated 9%)
#   adding: results/simple/without_mask/309.png (deflated 9%)
#   adding: results/simple/without_mask/135.png (deflated 9%)
#   adding: results/simple/without_mask/610.png (deflated 8%)
#   adding: results/simple/without_mask/703.png (deflated 8%)
#   adding: results/simple/without_mask/447.png (deflated 8%)
#   adding: results/simple/without_mask/955.png (deflated 8%)
#   adding: results/simple/without_mask/576.png (deflated 9%)
#   adding: results/simple/without_mask/434.png (deflated 8%)
#   adding: results/simple/without_mask/353.png (deflated 8%)
#   adding: results/simple/without_mask/706.png (deflated 8%)
#   adding: results/simple/without_mask/357.png (deflated 8%)
#   adding: results/simple/without_mask/721.png (deflated 9%)
#   adding: results/simple/without_mask/16.png (deflated 8%)
#   adding: results/simple/without_mask/190.png (deflated 8%)
#   adding: results/simple/without_mask/501.png (deflated 8%)
#   adding: results/simple/without_mask/337.png (deflated 9%)
#   adding: results/simple/without_mask/183.png (deflated 8%)
#   adding: results/simple/without_mask/770.png (deflated 8%)
#   adding: results/simple/without_mask/471.png (deflated 9%)
#   adding: results/simple/without_mask/57.png (deflated 9%)
#   adding: results/simple/without_mask/758.png (deflated 9%)
#   adding: results/simple/without_mask/597.png (deflated 8%)
#   adding: results/simple/without_mask/149.png (deflated 8%)
#   adding: results/simple/without_mask/653.png (deflated 9%)
#   adding: results/simple/without_mask/799.png (deflated 8%)
#   adding: results/simple/without_mask/759.png (deflated 9%)
#   adding: results/simple/without_mask/463.png (deflated 8%)
#   adding: results/simple/without_mask/757.png (deflated 8%)
#   adding: results/simple/without_mask/723.png (deflated 9%)
#   adding: results/simple/without_mask/277.png (deflated 9%)
#   adding: results/simple/without_mask/46.png (deflated 9%)
#   adding: results/simple/without_mask/136.png (deflated 8%)
#   adding: results/simple/without_mask/334.png (deflated 8%)
#   adding: results/simple/without_mask/268.png (deflated 8%)
#   adding: results/simple/without_mask/1.png (deflated 8%)
#   adding: results/simple/without_mask/694.png (deflated 8%)
#   adding: results/simple/without_mask/217.png (deflated 8%)
#   adding: results/simple/without_mask/465.png (deflated 8%)
#   adding: results/simple/without_mask/554.png (deflated 8%)
#   adding: results/simple/without_mask/265.png (deflated 9%)
#   adding: results/simple/without_mask/796.png (deflated 9%)
#   adding: results/simple/without_mask/358.png (deflated 8%)
#   adding: results/simple/without_mask/261.png (deflated 9%)
#   adding: results/simple/without_mask/189.png (deflated 8%)
#   adding: results/simple/without_mask/913.png (deflated 8%)
#   adding: results/simple/without_mask/29.png (deflated 8%)
#   adding: results/simple/without_mask/51.png (deflated 9%)
#   adding: results/simple/without_mask/942.png (deflated 9%)
#   adding: results/simple/without_mask/266.png (deflated 8%)
#   adding: results/simple/without_mask/936.png (deflated 9%)
#   adding: results/simple/without_mask/769.png (deflated 9%)
#   adding: results/simple/without_mask/408.png (deflated 8%)
#   adding: results/simple/without_mask/825.png (deflated 8%)
#   adding: results/simple/without_mask/388.png (deflated 8%)
#   adding: results/simple/without_mask/522.png (deflated 8%)
#   adding: results/simple/without_mask/738.png (deflated 8%)
#   adding: results/simple/without_mask/533.png (deflated 8%)
#   adding: results/simple/without_mask/73.png (deflated 9%)
#   adding: results/simple/without_mask/445.png (deflated 9%)
#   adding: results/simple/without_mask/921.png (deflated 9%)
#   adding: results/simple/without_mask/695.png (deflated 8%)
#   adding: results/simple/without_mask/887.png (deflated 8%)
#   adding: results/simple/without_mask/537.png (deflated 9%)
#   adding: results/simple/without_mask/347.png (deflated 8%)
#   adding: results/simple/without_mask/157.png (deflated 8%)
#   adding: results/simple/without_mask/716.png (deflated 8%)
#   adding: results/simple/without_mask/376.png (deflated 8%)
#   adding: results/simple/without_mask/409.png (deflated 9%)
#   adding: results/simple/without_mask/23.png (deflated 8%)
#   adding: results/simple/without_mask/515.png (deflated 8%)
#   adding: results/simple/without_mask/749.png (deflated 9%)
#   adding: results/simple/without_mask/308.png (deflated 8%)
#   adding: results/simple/without_mask/80.png (deflated 8%)
#   adding: results/simple/without_mask/682.png (deflated 9%)
#   adding: results/simple/without_mask/54.png (deflated 9%)
#   adding: results/simple/without_mask/994.png (deflated 8%)
#   adding: results/simple/without_mask/10.png (deflated 9%)
#   adding: results/simple/without_mask/500.png (deflated 8%)
#   adding: results/simple/without_mask/417.png (deflated 8%)
#   adding: results/simple/without_mask/531.png (deflated 8%)
#   adding: results/simple/without_mask/164.png (deflated 8%)
#   adding: results/simple/without_mask/69.png (deflated 8%)
#   adding: results/simple/without_mask/866.png (deflated 8%)
#   adding: results/simple/without_mask/122.png (deflated 9%)
#   adding: results/simple/without_mask/415.png (deflated 8%)
#   adding: results/simple/without_mask/882.png (deflated 8%)
#   adding: results/simple/without_mask/534.png (deflated 8%)
#   adding: results/simple/without_mask/607.png (deflated 9%)
#   adding: results/simple/without_mask/820.png (deflated 8%)
#   adding: results/simple/without_mask/475.png (deflated 9%)
#   adding: results/simple/without_mask/483.png (deflated 9%)
#   adding: results/simple/without_mask/609.png (deflated 8%)
#   adding: results/simple/without_mask/563.png (deflated 9%)
#   adding: results/simple/without_mask/215.png (deflated 9%)
#   adding: results/simple/without_mask/908.png (deflated 8%)
#   adding: results/simple/without_mask/53.png (deflated 8%)
#   adding: results/simple/without_mask/664.png (deflated 8%)
#   adding: results/simple/without_mask/368.png (deflated 8%)
#   adding: results/simple/without_mask/792.png (deflated 9%)
#   adding: results/simple/without_mask/699.png (deflated 9%)
#   adding: results/simple/without_mask/978.png (deflated 8%)
#   adding: results/simple/without_mask/340.png (deflated 8%)
#   adding: results/simple/without_mask/583.png (deflated 8%)
#   adding: results/simple/without_mask/322.png (deflated 8%)
#   adding: results/simple/without_mask/813.png (deflated 8%)
#   adding: results/simple/without_mask/247.png (deflated 8%)
#   adding: results/simple/without_mask/950.png (deflated 8%)
#   adding: results/simple/without_mask/640.png (deflated 9%)
#   adding: results/simple/without_mask/172.png (deflated 8%)
#   adding: results/simple/without_mask/880.png (deflated 8%)
#   adding: results/simple/without_mask/365.png (deflated 8%)
#   adding: results/simple/without_mask/207.png (deflated 9%)

# %%
# Google Colab으로부터 results.zip 압축 파일 다운로드
from google.colab import files

files.download('./results.zip')

# %% [markdown]
# ![image.png](data:image/png;base64,...)
